# %%
import json
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import pprint
import os
import pygaps
import scipy

# %%
class Isotherm:
    # In Python classes, there is one required function you have to define, __init__ (for initialization)
    def __init__(self, filename):
        # This if-else sentence loads in the isotherm data. If you have extracted the isotherms into your directory, 
        #  you will load it directly, but if you haven't you'll have to download it from the NIST database.
        if os.path.isfile('isotherms/' + filename + '.json'):
            with open('isotherms/' + filename + '.json') as infile:
                isotherm_data = json.load(infile)
        else:
            url = "https://adsorption.nist.gov/isodb/api/isotherm/" + filename + ".json"
            isotherm_data = json.loads(requests.get(url).content)

        
        self.filename = filename
        self.doi = isotherm_data['DOI']
        assert len(isotherm_data['adsorbates']) < 2
        self.adsorbate = isotherm_data['adsorbates'][0]['name']
        self.inchikey = isotherm_data['adsorbates'][0]['InChIKey']
        self.adsorbent = isotherm_data['adsorbent']['name']
        self.category = isotherm_data['category']
        self.temperature = isotherm_data['temperature']
        self.adsorptionUnits = isotherm_data['adsorptionUnits']
        self.pressureUnits = isotherm_data['pressureUnits']
        self.pressure = np.array([isotherm_data['isotherm_data'][i]['pressure'] for i in range(len(isotherm_data['isotherm_data']))])
        self.adsorption = np.array([isotherm_data['isotherm_data'][i]['species_data'][0]['adsorption'] for i in range(len(isotherm_data['isotherm_data']))])
        self.henry_constant = None
        
    # Lets define a few helper functions first
    def _get_formula_from_inchikey(self):
        # Usually if there's an underscore in front of a function name, 
        #  it's meant for internal use
        url = "https://adsorbents.nist.gov/isodb/api/gas/" + self.inchikey + ".json"
        gas_data = json.loads(requests.get(url).content)
        self.formula = gas_data['formula']
    
    def get_molecular_weight(self):
        self._get_formula_from_inchikey()
        # We will need to read in the atomic masses to compute the molecular weight (mw):
        atomic_masses = pd.read_csv('data/atomicmasses.csv')
        
        # This splits the formula up into elements plus their frequency
        start_i = 0
        elements = []
        for end_i, letter in enumerate(self.formula[1:], start=1):
            if letter.isupper():
                elements.append([start_i, end_i])
                start_i = end_i
        elements.append([start_i, len(self.formula)])

        # This calculates the molecular weight of each type of element
        self.mw = 0
        for element in elements:
            form = self.formula[element[0]:element[1]]
            for i, letter in enumerate(form):
                if letter.isdigit():
                    element_mw = np.float(atomic_masses[atomic_masses.atom == form[:i]]['mass'])
                    self.mw = self.mw + element_mw * np.int(form[i:])
                    break
                if form.isalpha():
                    element_mw = np.float(atomic_masses[atomic_masses.atom == form]['mass'])
                    self.mw = self.mw + element_mw
                    break
        return self.mw
        
    def convert_units(self):
        # This will convert the pressure and adsorption to 'bar' and 'mmol/g', respectively, if needed
        # Pressure Units:
        assert self.pressureUnits == 'bar'

        # Adsorption Units:
        assert self.adsorptionUnits in ['cm3(STP)/g','g/g','mg/g','ml/g','mmol/g','mmol/kg','mol/g','wt%']

        aConversion = 0.0
        if self.adsorptionUnits == 'mmol/g':
            aConversion = 1.0
        elif self.adsorptionUnits == 'mmol/kg':
            aConversion = 1.0 / 1000.0
        elif self.adsorptionUnits == 'mol/g':
            aConversion = 1000.0
        elif self.adsorptionUnits in ['wt%', 'g/g']:
            mw = self.get_molecular_weight()
            aConversion = 1000.0 / mw
        elif self.adsorptionUnits in ['ml/g', 'cm3(STP)/g']:
            aConversion = 1.0 / 22.4
        elif self.adsorptionUnits == 'mg/g':
            mw = self.get_molecular_weight()
            aConversion = 1.0 / mw
        else:
            raise Exception('Something went horribly wrong!')

        self.adsorption = self.adsorption * aConversion
        self.adsorptionUnits = 'mmol/g'
        
    def fit_henry_constant(self, max_adjrms, verbose):
        # This will fit a Henry constant to the adsorption isotherm.
        # `max_adjrms` is a parameter used for the fitting procedure. 
        #  The default value is 0.01, but we can play around with this.
        # `verbose=True` will create a plot of the fit and give additional information
        # If the adsorption units are not in 'mmol/g' and the pressure units are not in 'bar',
        #  the assertion below will throw an error. Use `convert_units` to switch to the correct units
        assert self.adsorptionUnits == 'mmol/g' and self.pressureUnits == 'bar'
        isotherm = pygaps.PointIsotherm(
            pressure=self.pressure,
            loading=self.adsorption,
            material_name=self.adsorbent,
            material_batch='',
            t_iso=self.temperature,
            adsorbate=self.adsorbate)
        try:
            self.henry_constant = pygaps.initial_henry_slope(isotherm, max_adjrms, logx=False, verbose=verbose)
            return self.henry_constant
        except Exception as e:
            self.error = e
            print('Fitting procedure failed! See `self.error` as to why...')
            
    def flag_isotherm(self, henry_df):
        henry_df['ok'].loc[henry_df['filename'] == self.filename] = False
        return
    
    def unflag_isotherm(self, henry_df):
        henry_df['ok'].loc[henry_df['filename'] == self.filename] = True
        return
    
    def add_comment(self, comment, henry_df):
        henry_df['comment'].loc[henry_df['filename'] == self.filename] = comment
        return
    
    def plot_isotherm(self):
        fig = plt.figure(figsize=(8,6))
        bad_datapoints = self.pressure[self.pressure < 0]
        good_datapoints = self.pressure[self.pressure >= 0]
        plt.scatter(self.pressure, self.adsorption, marker='o', label='Experimental')
        if self.henry_constant:
            plt.plot([0, self.pressure[-1]], [0, self.pressure[-1] * self.henry_constant], color='red', label="Henry's Law")
        plt.xlabel('Pressure [{}]'.format(self.pressureUnits))
        plt.ylabel('Adsorption [{}]'.format(self.adsorptionUnits))
        plt.ylim([-0.2*self.adsorption[-1], self.adsorption[-1] * 1.2])
        plt.legend()
        plt.show()
        return

# %%
henry_df = pd.read_csv('henry_df.csv')
henry_df.head(10)
# Out:
#    Unnamed: 0                          gas  \
# 0           0  CURLTUGMZLYLDI-UHFFFAOYSA-N
# 1           1  CURLTUGMZLYLDI-UHFFFAOYSA-N
# 2           2  CURLTUGMZLYLDI-UHFFFAOYSA-N
# 3           3  CURLTUGMZLYLDI-UHFFFAOYSA-N
# 4           4  CURLTUGMZLYLDI-UHFFFAOYSA-N
# 5           5  CURLTUGMZLYLDI-UHFFFAOYSA-N
# 6           6  CURLTUGMZLYLDI-UHFFFAOYSA-N
# 7           7  CURLTUGMZLYLDI-UHFFFAOYSA-N
# 8           8  CURLTUGMZLYLDI-UHFFFAOYSA-N
# 9           9  CURLTUGMZLYLDI-UHFFFAOYSA-N
#
#                                       material  henry_constant  \
# 0  NIST-MATDB-b2dc02871a66ac38e4b195796cf3e00b        0.466816
# 1  NIST-MATDB-b2dc02871a66ac38e4b195796cf3e00b        0.953870
# 2  NIST-MATDB-b2dc02871a66ac38e4b195796cf3e00b        0.290830
# 3  NIST-MATDB-b2dc02871a66ac38e4b195796cf3e00b        2.612494
# 4  NIST-MATDB-b2dc02871a66ac38e4b195796cf3e00b        0.962891
# 5  NIST-MATDB-b2dc02871a66ac38e4b195796cf3e00b        2.661777
# ...

# %%
henry_df.sort_values(["henry_constant"], ascending = False, inplace = True)
henry_df.head(50)
# Out:
#       Unnamed: 0                          gas  \
# 961          961  UGFAIRIUMAVXCW-UHFFFAOYSA-N
# 1560        1560  VNWKTOKETHGBQD-UHFFFAOYSA-N
# 1190        1190  VNWKTOKETHGBQD-UHFFFAOYSA-N
# 1191        1191  VNWKTOKETHGBQD-UHFFFAOYSA-N
# 1847        1847  HSFWRNGVRCDJHI-UHFFFAOYSA-N
# 1821        1821  HSFWRNGVRCDJHI-UHFFFAOYSA-N
# 1849        1849  HSFWRNGVRCDJHI-UHFFFAOYSA-N
# 1822        1822  HSFWRNGVRCDJHI-UHFFFAOYSA-N
# 1848        1848  HSFWRNGVRCDJHI-UHFFFAOYSA-N
# 1823        1823  HSFWRNGVRCDJHI-UHFFFAOYSA-N
# 1657        1657  XLYOFNOQVPJJNP-UHFFFAOYSA-N
# 1559        1559  VNWKTOKETHGBQD-UHFFFAOYSA-N
# 1800        1800  XLYOFNOQVPJJNP-UHFFFAOYSA-N
# 1659        1659  OKKJLVBELUTLKV-UHFFFAOYSA-N
# 1661        1661  LFQSCWFLJHTTHZ-UHFFFAOYSA-N
# 938          938  XLYOFNOQVPJJNP-UHFFFAOYSA-N
# 1654        1654  XLYOFNOQVPJJNP-UHFFFAOYSA-N
# 1660        1660  LFQSCWFLJHTTHZ-UHFFFAOYSA-N
# 1653        1653  XLYOFNOQVPJJNP-UHFFFAOYSA-N
# ...

# %%
henry_df = henry_df.drop(['gas', 'material', 'ok', 'z_score', 'comment'], axis=1)

# %%
henry_df['additional'] = ""
henry_df['water'] = ""
henry_df['units'] = ""
henry_df['ads_and_des'] = ""
henry_df['other'] = ""
#henry_df.drop(['ads and des'], axis=1)
#henry_df.drop(['comment'], axis=1)
#henry_df.drop(['additional', 'water', 'units', 'other', 'ads and des'], axis=1)
#henry_df.dropna(axis=1)
#comments = np.full(henry_df.shape[0], "")
#comment_df = pd.DataFrame(data={'comment': comments})
#henry_df.join(comment_df)
henry_df
# Out:
#       Unnamed: 0  henry_constant                                   filename  \
# 961          961    6.401857e+13   10.1016j.micromeso.2012.02.034.Isotherm2
# 1560        1560    3.662595e+09       10.1016j.fluid.2014.08.020.Isotherm3
# 1190        1190    2.593508e+09       10.1016j.fluid.2014.08.020.Isotherm2
# 1191        1191    2.485209e+09       10.1016j.fluid.2014.08.020.Isotherm1
# 1847        1847    3.377586e+08        10.1007s11224-012-0120-1.isotherm35
# 1821        1821    1.527369e+08        10.1007s11224-012-0120-1.isotherm36
# 1849        1849    9.760917e+06        10.1007s11224-012-0120-1.isotherm32
# 1822        1822    9.610024e+06        10.1007s11224-012-0120-1.isotherm34
# 1848        1848    9.362430e+06        10.1007s11224-012-0120-1.isotherm33
# 1823        1823    8.959582e+06        10.1007s11224-012-0120-1.isotherm31
# 1657        1657    6.510717e+06                 10.1021Jp1033273.Isotherm1
# ...

# %%
henry_df.other[henry_df.filename == '10.1016j.micromeso.2012.02.034.Isotherm2'] = 'Has a positive value for adsorption at a pressure of 0'
henry_df
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#       Unnamed: 0  henry_constant                                   filename  \
# 961          961    6.401857e+13   10.1016j.micromeso.2012.02.034.Isotherm2
# 1560        1560    3.662595e+09       10.1016j.fluid.2014.08.020.Isotherm3
# 1190        1190    2.593508e+09       10.1016j.fluid.2014.08.020.Isotherm2
# 1191        1191    2.485209e+09       10.1016j.fluid.2014.08.020.Isotherm1
# 1847        1847    3.377586e+08        10.1007s11224-012-0120-1.isotherm35
# 1821        1821    1.527369e+08        10.1007s11224-012-0120-1.isotherm36
# 1849        1849    9.760917e+06        10.1007s11224-012-0120-1.isotherm32
# ...

# %%
henry_df.additional[henry_df.filename == '10.1016j.fluid.2014.08.020.Isotherm3'] = 'X'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
henry_df.units[henry_df.filename == '10.1016j.fluid.2014.08.020.Isotherm2'] = 'X'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
henry_df.units[henry_df.filename == '10.1016j.fluid.2014.08.020.Isotherm1'] = 'X'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
#henry_df.other[henry_df.filename == '10.1007s11224-012-0120-1.isotherm35'] = 'X'
# scale of pressure is messed up should I store this in other?

# %%
#henry_df.other[henry_df.filename == '10.1007s11224-012-0120-1.isotherm36'] = 'X'
# scale of pressure is messed up same as previous should i store this in other?

# %%
henry_df.other[henry_df.filename == '10.1007s11224-012-0120-1.isotherm32'] = 'Has a positive value for adsorption at a pressure of 0'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
henry_df.other[henry_df.filename == '10.1007s11224-012-0120-1.isotherm34'] = 'Has a positive value for adsorption at a pressure of 0'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
henry_df.other[henry_df.filename == '10.1007s11224-012-0120-1.isotherm33'] = 'Has a positive value for adsorption at a pressure of 0'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
henry_df.other[henry_df.filename == '10.1007s11224-012-0120-1.isotherm31'] = 'Has a positive value for adsorption at a pressure of 0'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
henry_df.additional[henry_df.filename == '10.1021Jp1033273.Isotherm1'] = 'X'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
henry_df.units[henry_df.filename == '10.1016j.fluid.2014.08.020.Isotherm4'] = 'X'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
henry_df.water[henry_df.filename == '10.1002Aic.11362.Isotherm1'] = 'X'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
henry_df.additional[henry_df.filename == '10.1021Jp1033273.Isotherm3'] = 'X'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
henry_df.water[henry_df.filename == '10.1002Aic.11362.Isotherm2'] = 'X'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
henry_df.additional[henry_df.filename == '10.1021Jp1033273.Isotherm4'] = 'X'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
# henry_df.other[henry_df.filename == '10.1021Jp1033273.Isotherm7'] = 
# I think that they plotted this incorrectly severely 
# idk what to put here. There isnt info supporting these plot
# points for ethanol in the literature or the SI 
# there are also more points added than there are in the lit

# %%
# henry_df.other[henry_df.filename == '10.1021Jp1033273.Isotherm6'] =
# this has a similar issue as the previous isotherm. 
# There isnt supporting infor supporing these plot points 
# in the literature or the SI

# %%
henry_df.additional[henry_df.filename == '10.1021Jp1033273.Isotherm5'] = 'X'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
henry_df.additional[henry_df.filename == '10.1021La702466d.Isotherm3'] = 'X'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
henry_df.units[henry_df.filename == '10.1021Ja060946u.Isotherm9'] = 'X'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
henry_df.additional[henry_df.filename == '10.1021Ja060946u.Isotherm10'] = 'X'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
henry_df.other[henry_df.filename == '10.1039c5cc02809d.Isotherm6'] = 'Has a positive value for adsorption at a pressure of 0'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
henry_df.units[henry_df.filename == '10.1021Je800900a.Isotherm7'] = 'X'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
henry_df.units[henry_df.filename == '10.1021Je800900a.Isotherm29'] = 'X'
henry_df.additional[henry_df.filename == '10.1021Je800900a.Isotherm29'] = 'X'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
henry_df.units[henry_df.filename == '10.1021Je800900a.Isotherm8'] = 'X'
henry_df.additional[henry_df.filename == '10.1021Je800900a.Isotherm8'] = 'X'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
henry_df.additional[henry_df.filename == '10.1021Je800900a.Isotherm54'] = 'X'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
henry_df.additional[henry_df.filename == '10.1021Je800900a.Isotherm64'] = 'X'
henry_df.water[henry_df.filename == '10.1021Je800900a.Isotherm64'] = 'X'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
henry_df.ads_and_des[henry_df.filename == '10.1002anie.201506345.Isotherm6'] = 'X'
henry_df.water[henry_df.filename == '10.1002anie.201506345.Isotherm6'] = 'X'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# henry_df.other[henry_df.filename == '10.1039C3cc48275h.Isotherm18'] = 'There are fewer data points than there are in the literature. It looks like it was polotted incorrectly and plotted as the shape on the Pressure units(P/P_0) and then just pasted onto the scale of pressure units(mbar) which exhibits a different shape'
# relook at this

# %%
henry_df.other[henry_df.filename == '10.1021Je800900a.Isotherm63'] = 'Has a positive value for adsorption at a pressure of 0'
henry_df.water[henry_df.filename == '10.1021Je800900a.Isotherm63'] = 'X'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
henry_df.units[henry_df.filename == '10.1021La302537d.Isotherm40'] = 'X'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
henry_df.additional[henry_df.filename == '10.1021La302537d.Isotherm39'] = 'X'
henry_df.water[henry_df.filename == '10.1021La302537d.Isotherm39'] = 'X'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
henry_df.other[henry_df.filename == '10.1039C3cc48275h.Isotherm21'] = 'There are fewer data points than there are in the literature. It looks like it was polotted incorrectly and plotted as the shape on the Pressure units(P/P_0) and then just pasted onto the scale of pressure units(mbar) which exhibits a different shape'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
#henry_df.other[henry_df.filename == '10.1039C3cc48275h.Isotherm23'] = 'There are fewer data points than there are in the literature. It looks like it was polotted incorrectly and plotted as the shape on the Pressure units(P/P_0) and then just pasted onto the scale of pressure units(mbar) which exhibits a different shape.'

# %%
henry_df.units[henry_df.filename == '10.1016S1004-9541(07)60095-0.Isotherm9'] = 'X'
henry_df.other[henry_df.filename == '10.1016S1004-9541(07)60095-0.Isotherm9'] = 'There is a very apparent mistake in one point that is not present in the original literature.'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
henry_df.units[henry_df.filename == '10.1021la010232r.Isotherm6'] = 'X'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
henry_df.units[henry_df.filename == '10.1021Ja060946u.Isotherm8'] = 'X'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
