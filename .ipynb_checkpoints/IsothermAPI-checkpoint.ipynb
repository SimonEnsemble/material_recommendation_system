# %% [markdown]
# # Analyze adsorption isotherm anomalies

# %%
import json
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import pprint
import os
import pygaps
import scipy

# %% [markdown]
# ## Lets make a Python class for an adsorption isotherm

# %% [markdown]
# ### This is usually referred to as class-based Object-Oriented Programming (OOP).

# %% [markdown]
# #### [Here](https://pythonprogramming.net/introduction-learn-python-3-tutorials/)'s a tutorial series on Python if you want to learn the basics, and [Here](https://pythonprogramming.net/introduction-intermediate-python-tutorial/)'s an intermediate Python tutorial if the basic one is too easy.
#
# #### More specifically, [This](https://pythonprogramming.net/object-oriented-programming-introduction-intermediate-python-tutorial/) is a tutorial on OOP in Python that I recommend, which introduces Classes

# %%
class Isotherm:
    # In Python classes, there is one required function you have to define, __init__ (for initialization)
    def __init__(self, filename):
        # This if-else sentence loads in the isotherm data. If you have extracted the isotherms into your directory, 
        #  you will load it directly, but if you haven't you'll have to download it from the NIST database.
        if os.path.isfile('isotherms/' + filename + '.json'):
            with open('isotherms/' + filename + '.json') as infile:
                isotherm_data = json.load(infile)
        else:
            url = "https://adsorption.nist.gov/isodb/api/isotherm/" + filename + ".json"
            isotherm_data = json.loads(requests.get(url).content)

        
        self.filename = filename
        self.doi = isotherm_data['DOI']
        assert len(isotherm_data['adsorbates']) < 2
        self.adsorbate = isotherm_data['adsorbates'][0]['name']
        self.inchikey = isotherm_data['adsorbates'][0]['InChIKey']
        self.adsorbent = isotherm_data['adsorbent']['name']
        self.category = isotherm_data['category']
        self.temperature = isotherm_data['temperature']
        self.adsorptionUnits = isotherm_data['adsorptionUnits']
        self.pressureUnits = isotherm_data['pressureUnits']
        self.pressure = np.array([isotherm_data['isotherm_data'][i]['pressure'] for i in range(len(isotherm_data['isotherm_data']))])
        self.adsorption = np.array([isotherm_data['isotherm_data'][i]['species_data'][0]['adsorption'] for i in range(len(isotherm_data['isotherm_data']))])
        self.henry_constant = None
        
    # Lets define a few helper functions first
    def _get_formula_from_inchikey(self):
        # Usually if there's an underscore in front of a function name, 
        #  it's meant for internal use
        url = "https://adsorbents.nist.gov/isodb/api/gas/" + self.inchikey + ".json"
        gas_data = json.loads(requests.get(url).content)
        self.formula = gas_data['formula']
    
    def get_molecular_weight(self):
        self._get_formula_from_inchikey()
        # We will need to read in the atomic masses to compute the molecular weight (mw):
        atomic_masses = pd.read_csv('data/atomicmasses.csv')
        
        # This splits the formula up into elements plus their frequency
        start_i = 0
        elements = []
        for end_i, letter in enumerate(self.formula[1:], start=1):
            if letter.isupper():
                elements.append([start_i, end_i])
                start_i = end_i
        elements.append([start_i, len(self.formula)])

        # This calculates the molecular weight of each type of element
        self.mw = 0
        for element in elements:
            form = self.formula[element[0]:element[1]]
            for i, letter in enumerate(form):
                if letter.isdigit():
                    element_mw = np.float(atomic_masses[atomic_masses.atom == form[:i]]['mass'])
                    self.mw = self.mw + element_mw * np.int(form[i:])
                    break
                if form.isalpha():
                    element_mw = np.float(atomic_masses[atomic_masses.atom == form]['mass'])
                    self.mw = self.mw + element_mw
                    break
        return self.mw
        
    def convert_units(self):
        # This will convert the pressure and adsorption to 'bar' and 'mmol/g', respectively, if needed
        # Pressure Units:
        assert self.pressureUnits == 'bar'

        # Adsorption Units:
        assert self.adsorptionUnits in ['cm3(STP)/g','g/g','mg/g','ml/g','mmol/g','mmol/kg','mol/g','wt%']

        aConversion = 0.0
        if self.adsorptionUnits == 'mmol/g':
            aConversion = 1.0
        elif self.adsorptionUnits == 'mmol/kg':
            aConversion = 1.0 / 1000.0
        elif self.adsorptionUnits == 'mol/g':
            aConversion = 1000.0
        elif self.adsorptionUnits in ['wt%', 'g/g']:
            mw = self.get_molecular_weight()
            aConversion = 1000.0 / mw
        elif self.adsorptionUnits in ['ml/g', 'cm3(STP)/g']:
            aConversion = 1.0 / 22.4
        elif self.adsorptionUnits == 'mg/g':
            mw = self.get_molecular_weight()
            aConversion = 1.0 / mw
        else:
            raise Exception('Something went horribly wrong!')

        self.adsorption = self.adsorption * aConversion
        self.adsorptionUnits = 'mmol/g'
        
    def fit_henry_constant(self, max_adjrms, verbose):
        # This will fit a Henry constant to the adsorption isotherm.
        # `max_adjrms` is a parameter used for the fitting procedure. 
        #  The default value is 0.01, but we can play around with this.
        # `verbose=True` will create a plot of the fit and give additional information
        # If the adsorption units are not in 'mmol/g' and the pressure units are not in 'bar',
        #  the assertion below will throw an error. Use `convert_units` to switch to the correct units
        assert self.adsorptionUnits == 'mmol/g' and self.pressureUnits == 'bar'
        isotherm = pygaps.PointIsotherm(
            pressure=self.pressure,
            loading=self.adsorption,
            material_name=self.adsorbent,
            material_batch='',
            t_iso=self.temperature,
            adsorbate=self.adsorbate)
        try:
            self.henry_constant = pygaps.initial_henry_slope(isotherm, max_adjrms, logx=False, verbose=verbose)
            return self.henry_constant
        except Exception as e:
            self.error = e
            print('Fitting procedure failed! See `self.error` as to why...')
            
    def flag_isotherm(self, henry_df):
        henry_df['ok'].loc[henry_df['filename'] == self.filename] = False
        return
    
    def unflag_isotherm(self, henry_df):
        henry_df['ok'].loc[henry_df['filename'] == self.filename] = True
        return
    
    def add_comment(self, comment, henry_df):
        henry_df['comment'].loc[henry_df['filename'] == self.filename] = comment
        return
    
    def plot_isotherm(self):
        fig = plt.figure(figsize=(8,6))
        bad_datapoints = self.pressure[self.pressure < 0]
        good_datapoints = self.pressure[self.pressure >= 0]
        plt.scatter(self.pressure, self.adsorption, marker='o', label='Experimental')
        if self.henry_constant:
            plt.plot([0, self.pressure[-1]], [0, self.pressure[-1] * self.henry_constant], color='red', label="Henry's Law")
        plt.xlabel('Pressure [{}]'.format(self.pressureUnits))
        plt.ylabel('Adsorption [{}]'.format(self.adsorptionUnits))
        plt.ylim([-0.2*self.adsorption[-1], self.adsorption[-1] * 1.2])
        plt.legend()
        plt.show()
        return

# %%
henry_df = pd.read_csv('henry_df.csv')
henry_df.head(10)
# Out:
#    Unnamed: 0                          gas  \
# 0           0  CURLTUGMZLYLDI-UHFFFAOYSA-N
# 1           1  CURLTUGMZLYLDI-UHFFFAOYSA-N
# 2           2  CURLTUGMZLYLDI-UHFFFAOYSA-N
# 3           3  CURLTUGMZLYLDI-UHFFFAOYSA-N
# 4           4  CURLTUGMZLYLDI-UHFFFAOYSA-N
# 5           5  CURLTUGMZLYLDI-UHFFFAOYSA-N
# 6           6  CURLTUGMZLYLDI-UHFFFAOYSA-N
# 7           7  CURLTUGMZLYLDI-UHFFFAOYSA-N
# 8           8  CURLTUGMZLYLDI-UHFFFAOYSA-N
# 9           9  CURLTUGMZLYLDI-UHFFFAOYSA-N
#
#                                       material  henry_constant  \
# 0  NIST-MATDB-b2dc02871a66ac38e4b195796cf3e00b        0.466816
# 1  NIST-MATDB-b2dc02871a66ac38e4b195796cf3e00b        0.953870
# 2  NIST-MATDB-b2dc02871a66ac38e4b195796cf3e00b        0.290830
# 3  NIST-MATDB-b2dc02871a66ac38e4b195796cf3e00b        2.612494
# 4  NIST-MATDB-b2dc02871a66ac38e4b195796cf3e00b        0.962891
# 5  NIST-MATDB-b2dc02871a66ac38e4b195796cf3e00b        2.661777
# ...

# %%
henry_df.sort_values(["henry_constant"], ascending = False, inplace = True)
henry_df.head(50)
# Out:
#       Unnamed: 0                          gas  \
# 961          961  UGFAIRIUMAVXCW-UHFFFAOYSA-N
# 1560        1560  VNWKTOKETHGBQD-UHFFFAOYSA-N
# 1190        1190  VNWKTOKETHGBQD-UHFFFAOYSA-N
# 1191        1191  VNWKTOKETHGBQD-UHFFFAOYSA-N
# 1847        1847  HSFWRNGVRCDJHI-UHFFFAOYSA-N
# 1821        1821  HSFWRNGVRCDJHI-UHFFFAOYSA-N
# 1849        1849  HSFWRNGVRCDJHI-UHFFFAOYSA-N
# 1822        1822  HSFWRNGVRCDJHI-UHFFFAOYSA-N
# 1848        1848  HSFWRNGVRCDJHI-UHFFFAOYSA-N
# 1823        1823  HSFWRNGVRCDJHI-UHFFFAOYSA-N
# 1657        1657  XLYOFNOQVPJJNP-UHFFFAOYSA-N
# 1559        1559  VNWKTOKETHGBQD-UHFFFAOYSA-N
# 1800        1800  XLYOFNOQVPJJNP-UHFFFAOYSA-N
# 1659        1659  OKKJLVBELUTLKV-UHFFFAOYSA-N
# 1661        1661  LFQSCWFLJHTTHZ-UHFFFAOYSA-N
# 938          938  XLYOFNOQVPJJNP-UHFFFAOYSA-N
# 1654        1654  XLYOFNOQVPJJNP-UHFFFAOYSA-N
# 1660        1660  LFQSCWFLJHTTHZ-UHFFFAOYSA-N
# 1653        1653  XLYOFNOQVPJJNP-UHFFFAOYSA-N
# ...

# %%
bad_iso = Isotherm('10.1016j.micromeso.2012.02.034.Isotherm2')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(1e20, True)
bad_iso.add_comment("has a positive adsorption at 0 pressure", henry_df)
# Out:
# mmol/g
# Calculated K = 0.18250830121294678
# Starting points: 30
# Selected points: 30
# Final adjusted root mean square difference: 0.25499231347032525
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
bad_iso = Isotherm('10.1016j.fluid.2014.08.020.Isotherm3')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(0.01, True)
bad_iso.add_comment("has positive adsorption at a pressure of 0 bars or close to it, incorrect unit conversion on NIST, more points than given in research", henry_df)
# Out:
# mg/g
# Calculated K = 3892269707.3685594
# Starting points: 71
# Selected points: 24
# Final adjusted root mean square difference: 0.009833807289993944

# %%
bad_iso = Isotherm('10.1016j.fluid.2014.08.020.Isotherm2')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(0.01, True)
bad_iso.add_comment("incorrect unit conversion on NIST, uncategorized but likely was simulated", henry_df)
# Out:
# mg/g
# Calculated K = 699239301.929995
# Starting points: 70
# Selected points: 3
# Final adjusted root mean square difference: 0.008997130838484442

# %%
bad_iso = Isotherm('10.1016j.fluid.2014.08.020.Isotherm1')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(0.01, True)
bad_iso.add_comment("incorrect unit conversion on NIST, uncategorized and 10.1016j.fluid.2014.08.020.Isotherm2 is likely the simulated experiment while this appears to be the experimental", henry_df)
# Out:
# mg/g
# Calculated K = 745585353.2862417
# Starting points: 15
# Selected points: 2
# Final adjusted root mean square difference: 6.0421690632257134e-12

# %%
bad_iso = Isotherm('10.1007s11224-012-0120-1.isotherm35')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(0.01, True)
bad_iso.add_comment("scale of pressure is incorrect, but units match, most of experimental points occur at a very low pressure, adsorption plateaus very early", henry_df)
# Out:
# cm3(STP)/g
# Calculated K = 337758554.374089
# Starting points: 16
# Selected points: 9
# Final adjusted root mean square difference: 0.008224406129350655

# %%
bad_iso = Isotherm('10.1007s11224-012-0120-1.isotherm36')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(0.01, True)
bad_iso.add_comment("scale of pressure is incorrect, but units match, most of experimental points occur at a very low pressure, adsorption plateaus very quickly", henry_df)
# Out:
# cm3(STP)/g
# Calculated K = 182581100.45803702
# Starting points: 16
# Selected points: 9
# Final adjusted root mean square difference: 0.007210087136245317

# %%
bad_iso = Isotherm('10.1007s11224-012-0120-1.isotherm32')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(1e20, True)
bad_iso.add_comment("the initial slope when pressure > 0 is very high and then the adsorption plateaus very soon after", henry_df)
# Out:
# cm3(STP)/g
# Calculated K = 23.93602655625188
# Starting points: 19
# Selected points: 19
# Final adjusted root mean square difference: 0.6691727503346535

# %%
bad_ibad_iso = Isotherm('10.1007s11224-012-0120-1.isotherm34')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(1e20, True)
bad_iso.add_comment("the initial slope when pressure > 0 is very high and then the adsorption plateaus very soon after, the Henry model is a line that is about y=25*x, intersects at single point on the experimental data and is not remotely close to the experimental curve at any other point", henry_df)
# Out:
# mmol/g
# Calculated K = 21.99364129335572
# Starting points: 18
# Selected points: 18
# Final adjusted root mean square difference: 0.7109624390325431

# %%
bad_iso = Isotherm('10.1007s11224-012-0120-1.isotherm33')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(1e20, True)
bad_iso.add_comment("the initial slope when pressure > 0 is very high and then the adsorption plateaus very soon after, the Henry model is a line that is about y=25*x, intersects at single point on the experimental data and is not remotely close to the experimental curve at any other point", henry_df)
# Out:
# cm3(STP)/g
# Calculated K = 21.99364129335572
# Starting points: 18
# Selected points: 18
# Final adjusted root mean square difference: 0.7109624390325431

# %%
bad_iso = Isotherm('10.1007s11224-012-0120-1.isotherm31')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(1e20, True)
bad_iso.add_comment("the initial slope when pressure > 0 is very high and then the adsorption plateaus very soon after, the Henry model is a line that is about y=25*x, intersects at single point on the experimental data and is not remotely close to the experimental curve at any other point", henry_df)
# Out:
# cm3(STP)/g
# Calculated K = 26.887822587150545
# Starting points: 18
# Selected points: 18
# Final adjusted root mean square difference: 0.638428815565957

# %%
bad_iso = Isotherm('10.1021Jp1033273.Isotherm1')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(1e20, True)
bad_iso.add_comment("According to the literature, the water saturated at 3.1 kPA, which correctly corresponds to .031 bar as shown on the plot, the henry model follows a line close to y=50*x and does not intersect the experimental plot until approximately 4 bar after it had plateuad. There are more points than there are in the literature.", henry_df)
# Out:
# mmol/g
# Calculated K = 63.14908687942719
# Starting points: 48
# Selected points: 48
# Final adjusted root mean square difference: 0.520550507248056

# %%
bad_iso = Isotherm('10.1016j.fluid.2014.08.020.Isotherm4')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(1e20, True)
bad_iso.add_comment("Incorrect conversion of pressure", henry_df)
# Out:
# mg/g
# Calculated K = 2352967181.656397
# Starting points: 19
# Selected points: 19
# Final adjusted root mean square difference: 0.1085964059648492

# %%
bad_iso = Isotherm('10.1002Aic.11362.Isotherm1')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(1e20, True)
bad_iso.add_comment("The water saturated very quickly which is consistent with the literature. Pressure is recorded in units of P/p_0 which is 'the ratio of H20 vapor pressure to saturation pressure of H20 at 298 K.' This conversion could have been done incorrectly", henry_df)
# Out:
# wt%
# Calculated K = 168213.1703003
# Starting points: 10
# Selected points: 10
# Final adjusted root mean square difference: 0.623306372307991

# %%
bad_iso = Isotherm('10.1021Jp1033273.Isotherm2')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(1e20, True)
bad_iso.add_comment("The literature states that methanol saturated at 16.8 kPa, which is consistent with the plot below. When P > 0, the initial slope is very high, and it plateaus shortly after. There are more points than there are in the literature.", henry_df)
# Out:
# mmol/g
# Calculated K = 20.731727840477834
# Starting points: 43
# Selected points: 43
# Final adjusted root mean square difference: 0.6348348358739825

# %%
bad_iso = Isotherm('10.1021Jp1033273.Isotherm3')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(1e20, True)
bad_iso.add_comment("The literature states that ethanol saturated at 7.2 kPa which corresponds to 0.072 bar and that is consistent with the plot. There are dips in the plot where the adsorption exhibits a negative slope. This is not present in the plot in the original literature. There are also more points than there are in the literature.", henry_df)
# Out:
# mmol/g
# Calculated K = 15.085729092171128
# Starting points: 41
# Selected points: 41
# Final adjusted root mean square difference: 0.7388724907919857

# %%
bad_iso = Isotherm('10.1002Aic.11362.Isotherm2')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(1e20, True)
bad_iso.add_comment("The water saturated very quickly which is consistent with the literature. Pressure is recorded in units of P/p_0 which is 'the ratio of H20 vapor pressure to saturation pressure of H20 at 298 K.' This conversion could have been done incorrectly", henry_df)
# Out:
# wt%
# Calculated K = 107180.16591469652
# Starting points: 8
# Selected points: 8
# Final adjusted root mean square difference: 0.6150098165096026

# %%
bad_iso = Isotherm('10.1021Jp1033273.Isotherm4')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(1e20, True)
bad_iso.add_comment("There are more points added than are included in the literature. Literature also includes a logaithmic scale. This is a water and methanol equimolar mixture", henry_df)
# Out:
# mmol/g
# Calculated K = 34.697149273793066
# Starting points: 43
# Selected points: 43
# Final adjusted root mean square difference: 0.4139263339626932

# %%
bad_iso = Isotherm('10.1021Jp1033273.Isotherm7')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(1e20, True)
bad_iso.add_comment("There are more points than there are in the literature. Almost this entire data set is different from the literature. In the literature, ethanol alone plateus at about 8 mmol/g. That is shown in 10.1021Jp1033273.Isotherm3. In an equimolar mixture of ethanol and water, ethanol plateaus at 5 mmol/g. There is no data from the literature that displays the points that are here. There are also more points than there are in the literature.", henry_df)
# Out:
# mmol/g
# Calculated K = 35.50989787816381
# Starting points: 41
# Selected points: 41
# Final adjusted root mean square difference: 0.4303768726807748

# %%
bad_iso = Isotherm('10.1021Jp1033273.Isotherm6')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(1e20, True)
bad_iso.add_comment("There is no data from the literature that shows water plateuing near 3.5 mmol/g with Na-Rho-ZMOF.", henry_df)
# Out:
# mmol/g
# Calculated K = 5.680659541246487
# Starting points: 41
# Selected points: 41
# Final adjusted root mean square difference: 0.7112289284301843

# %%
bad_iso = Isotherm('10.1021Jp1033273.Isotherm5')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(1e20, True)
bad_iso.add_comment("There are more data points than there are in the literature. This is an equimolar mixture of water and methanol", henry_df)
# Out:
# mmol/g
# Calculated K = 8.126315006928484
# Starting points: 39
# Selected points: 39
# Final adjusted root mean square difference: 0.6213757500411959

# %%
bad_iso = Isotherm('10.1021La702466d.Isotherm3')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(1e20, True)
bad_iso.add_comment("There are more data points than there are in the literature. The trend in the plot fits the trend displayed in the literature. The original literature uses pressure units of P/P_0 which could have been converted incorrectely.", henry_df)
# Out:
# wt%
# Calculated K = 302809.5319165749
# Starting points: 14
# Selected points: 14
# Final adjusted root mean square difference: 0.4823400936859459

# %%
bad_iso = Isotherm('10.1021Ja060946u.Isotherm9')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(1e20, True)
#bad_iso.add_comment("come back to this. The plot in the literature is incredibly hard to decipher. It appears that NIST may have recorded points for the desporption rather than the adsorption.", henry_df)
# Out:
# wt%
# Calculated K = 2901.3035140551356
# Starting points: 20
# Selected points: 20
# Final adjusted root mean square difference: 0.43074606457845216
# 2901.3035140551356

# %%
bad_iso = Isotherm('10.1021Ja060946u.Isotherm10')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(1e20, True)
bad_iso.add_comment("The plot in the literature is very poor and plots several sets of experimental data with symbols on the same plot. There are more points than are given in the literature.", henry_df)
# Out:
# wt%
# Calculated K = 1840.92398791464
# Starting points: 30
# Selected points: 30
# Final adjusted root mean square difference: 0.5133714011066971

# %%
bad_iso = Isotherm('10.1039c5cc02809d.Isotherm6')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(1e20, True)
bad_iso.add_comment("The initial slope is so high that it appears to be a vertical line. The literature recorded pressure in mbar, and even with units that small, the change in pressure is almost indistinguishable and the adsorption increases to almost saturation before the pressure noticeably changes. This could have been plotted incorrectly in NIST due to human error as the change in x for the first 7 points is almost, if not, indistinguishable to the human eye.", henry_df)
# Out:
# mmol/g
# Calculated K = 74.01064711110459
# Starting points: 34
# Selected points: 34
# Final adjusted root mean square difference: 0.4280720213647242

# %%
bad_iso = Isotherm('10.1021Je800900a.Isotherm7')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(1e20, True)
bad_iso.add_comment("There is an error in unit conversion here. The literature uses units of mol/kg, but the algorithm thinks the data is in mol/g. The literature uses a logarithmic scale, and it seems as though there is a lot of error in plotting points for linear scales from logarithmic plots.", henry_df)
# Out:
# mol/g
# Calculated K = 13588.419467203043
# Starting points: 17
# Selected points: 17
# Final adjusted root mean square difference: 0.24331722468022166

# %%
bad_iso = Isotherm('10.1021Je800900a.Isotherm29')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(1e20, True)
bad_iso.add_comment("There is an error in unit conversion here. The literature uses units of mol/kg, but the algorithm thinks the data is in mol/g. There are more points than there are in the literature. The literature uses a logarithmic scale, and it seems as though there is significant error in plotting points for linear scales from logarithmic plots.", henry_df)
# Out:
# mol/g
# Calculated K = 8031.213460415733
# Starting points: 40
# Selected points: 40
# Final adjusted root mean square difference: 0.2489001404453654

# %%
bad_iso = Isotherm('10.1021Je800900a.Isotherm8')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(1e20, True)
bad_iso.add_comment("There is an error in unit conversion here. The literature uses units of mol/kg, but the algorithm thinks the data is in mol/g. There are more points than there are in the literature. The literature uses a logarithmic scale, and it seems as though there is significant error in plotting points for linear scales from logarithmic plots. NIST also has made the max apsorption point higher than anything recorded in the literature for CO2 and Zeolite 5A.", henry_df)
# Out:
# mol/g
# Calculated K = 9106.505888131778
# Starting points: 48
# Selected points: 48
# Final adjusted root mean square difference: 0.20586466377360496

# %%
bad_iso = Isotherm('10.1021Je800900a.Isotherm54')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(1e20, True)
bad_iso.add_comment("There are more points than there are in the literature. The literature uses a logarithmic scale, and it seems as though there is significant error in plotting points for linear scales from logarithmic plots.", henry_df)
# Out:
# mmol/g
# Calculated K = 640.020017725939
# Starting points: 43
# Selected points: 43
# Final adjusted root mean square difference: 0.47415575016260497

# %%
bad_iso = Isotherm('10.1021Je800900a.Isotherm64')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(1e20, True)
bad_iso.add_comment("There are way more points than there are in the literature. The H2O saturated quickly and the data in the literature is recorded on a logarithmic scale which may have increased the human error by NIST.", henry_df)
# Out:
# mmol/g
# Calculated K = 666.1731858213358
# Starting points: 45
# Selected points: 45
# Final adjusted root mean square difference: 0.5614728225813947

# %%
bad_iso = Isotherm('10.1002anie.201506345.Isotherm6')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(1e20, True)
bad_iso.add_comment("This is from the supporting data. The reason why there are 3 instances of negative slopes is because they plotted points that represented the desorption instead of only the adsorption points. Thus there are more points than there are in the literature and the plot is just incorrect.", henry_df)
# Out:
# wt%
# Calculated K = 47047.4679405289
# Starting points: 38
# Selected points: 38
# Final adjusted root mean square difference: 0.34887081999897784

# %%
bad_iso = Isotherm('10.1039C3cc48275h.Isotherm18')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(1e20, True)
bad_iso.add_comment("There are fewer data points than there are in the literature. It looks like it was polotted incorrectly and plotted as the shape on the Pressure units(P/P_0) and then just pasted onto the scale of pressure units(mbar) which exhibits a different shape", henry_df)
# Out:
# wt%
# Calculated K = 192666.82453258595
# Starting points: 13
# Selected points: 13
# Final adjusted root mean square difference: 0.13148742728030474

# %%
bad_iso = Isotherm('10.1021Je800900a.Isotherm63')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(1e20, True)
bad_iso.add_comment("The experimental data has only 5 points. The initial slope is very fast and then the slope plateaus very shortly after. The original data uses a logarithmic pressure scale so there may be human error in plotting it on the linear plot as the early data points are at very low pressures.", henry_df)
# Out:
# mmol/g
# Calculated K = 903.3730849352852
# Starting points: 6
# Selected points: 6
# Final adjusted root mean square difference: 0.47831436255843673

# %%
bad_iso = Isotherm('10.1021La302537d.Isotherm40')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(1e20, True)
bad_iso.add_comment("This is simulated data. There is an incorrect unit conversion. The algorithm thinks that the adsorption units used in the literature is weight % when it is actually mmol/g. The pressure scale is incorrect. In the literature the pressure is measured in units of atm and there are points extending to 1.0 atm.", henry_df)
# Out:
# wt%
# Calculated K = 87331.18107419202
# Starting points: 31
# Selected points: 31
# Final adjusted root mean square difference: 0.14728494986717908

# %%
bad_iso = Isotherm('10.1021La302537d.Isotherm39')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(1e20, True)
bad_iso.add_comment("This is from the supporting materials of the literature. There seems to be only a single experimental data point, and the curve plotted is a DSLF fit", henry_df)
# Out:
# wt%
# Calculated K = 85547.28845123555
# Starting points: 11
# Selected points: 11
# Final adjusted root mean square difference: 0.14351963884676175

# %%
bad_iso = Isotherm('10.1039C3cc48275h.Isotherm21')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(1e20, True)
bad_iso.add_comment("There are fewer data points than there are in the literature. It looks like it was polotted incorrectly and plotted as the shape on the Pressure units(P/P_0) and then just pasted onto the scale of pressure units(mbar) which exhibits a different shape", henry_df)
# Out:
# wt%
# Calculated K = 416448.05998832907
# Starting points: 10
# Selected points: 10
# Final adjusted root mean square difference: 0.18665172386823814

# %%
bad_iso = Isotherm('10.1039C3cc48275h.Isotherm23')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(1e20, True)
bad_iso.add_comment("There are fewer data points than there are in the literature. It looks like it was polotted incorrectly and plotted as the shape on the Pressure units(P/P_0) and then just pasted onto the scale of pressure units(mbar) which exhibits a different shape. Cyclohexane is also not in the internal absorbent list", henry_df)
# Out:
# wt%
# Calculated K = 395584.40442169184
# Starting points: 11
# Selected points: 11
# Final adjusted root mean square difference: 0.1805760896131067

# %%
bad_iso = Isotherm('10.1016S1004-9541(07)60095-0.Isotherm9')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(1e20, True)
bad_iso.add_comment("The unit conversion is incorrect. The algorithm thinks the adsorption data is measured in weight % when it is actually measured in mmol/g. There is a huge error point in the NIST data that is just not present in the original literature.", henry_df)
# Out:
# wt%
# Calculated K = 167.2873355895913
# Starting points: 13
# Selected points: 13
# Final adjusted root mean square difference: 0.5136092309882647

# %%
bad_iso = Isotherm('10.1021la010232r.Isotherm6')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(1e20, True)
bad_iso.add_comment("This is simulated, predicted data. There is also an error in the conversion of the adsorption units. The algorithm thinks the adsorption in the data was measured in mmol/g when it was actually measured in mol/g", henry_df)
# Out:
# mmol/g
# Calculated K = 211.79640967403603
# Starting points: 23
# Selected points: 23
# Final adjusted root mean square difference: 0.5390245332393795

# %%
bad_iso = Isotherm('10.1021Ja060946u.Isotherm8')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(1e20, True)
bad_iso.add_comment("Adsorption units from literature measured in wt%, and pressure units measured in P/P_0, both of which could have been converted incorretly", henry_df)
# Out:
# wt%
# Calculated K = 7570.671249351756
# Starting points: 27
# Selected points: 27
# Final adjusted root mean square difference: 0.47036949865262945

# %%
bad_iso = Isotherm('10.1016j.micromeso.2012.02.027.isotherm7')
print(bad_iso.adsorptionUnits)
bad_iso.convert_units()
bad_iso.fit_henry_constant(1e20, True)
bad_iso.add_comment("It looks like the NIST plot for this is actually for the MOF MIL-100(Fe)_NF7. MIL-100(Fe) and MIL-100(Fe)_NF7 have almost identical trends except the latter curves upward instead of continuing a plateau at the end of the data. It appears that the data for MIL-100(Fe)_NF7 was recorded incorrectly under MIL-100(Fe). The Adsorption units from literature measured in wt%, and pressure units measured in P/P_0, both of which could have been converted incorretly", henry_df)
# Out:
# wt%
# Calculated K = 1984.7306830014097
# Starting points: 20
# Selected points: 20
# Final adjusted root mean square difference: 0.26480283934038024
