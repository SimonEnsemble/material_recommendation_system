# %% [markdown]
# # Primer on AiiDA

# %% [markdown]
# ## * AiiDA stands for <u>A</u>utomated <u>I</u>nteractive <u>I</u>nfrastructure and <u>Da</u>tabase for Computational Science<br>
# ## * Great for reproducibility

# %% [markdown]
# #### AiiDA is a database comprised of <b>Process Nodes</b> and <b>Data Nodes</b><br>
# #### The <b>Nodes</b> are connected with directed <b>edges</b> or <b>links</b>

# %% [markdown]
# <img src="fig1.jpg" width="800" height="400">

# %% [markdown]
# <div style="text-align: center"><span style="font-size:0.9em;">Computational Materials Science
# Volume 111, January 2016, Pages 218-230</span></div>

# %% [markdown]
# Here <b>Process Nodes</b> are represented by squares.<br>
# They orchestrate the calculations done, by gathering the necessary input data and outputting the results<br><br>
# The <b>Data Nodes</b> are represented by circles and store inputs and/or outputs of the calculations<br><br>

# %% [markdown]
# ### Example of <b>Node</b> attributes

# %% [markdown]
# <img src="fig3.jpg" width="800" height="400">

# %% [markdown]
# <div style="text-align: center"><span style="font-size:0.9em;">Computational Materials Science
# Volume 111, January 2016, Pages 218-230</span></div>

# %% [markdown]
# Here we have a <b>Process Node</b> with the <u>Primary Key (pk)</u>: 7<br>
# This node contains the information needed to run some kind of calculation.<br><br>
# The second node with pk: 8 is a <b>Data Node</b> with the results of a calculation

# %% [markdown]
# ### An example of a Calculation

# %% [markdown]
# <img src="fig4.jpg" width="800" height="400">

# %% [markdown]
# <div style="text-align: center"><span style="font-size:0.9em;">Computational Materials Science
# Volume 111, January 2016, Pages 218-230</span></div>

# %% [markdown]
# ### Overview of AiiDA

# %% [markdown]
# <img src="fig2.jpg" width="800" height="400">

# %% [markdown]
# <div style="text-align: center"><span style="font-size:0.9em;">Computational Materials Science
# Volume 111, January 2016, Pages 218-230</span></div>

# %% [markdown]
# There are three ways of using the AiiDA database. Here we'll only look at link between the AiiDA API and the Storage (to retrieve data) and omit the AiiDA daemon from our discussion

# %% [markdown]
# First you'll need to install necessary prerequisites and the aiida python package (via pip), see info here https://aiida.readthedocs.io/projects/aiida-core/en/latest/intro/get_started.html <br>
# (I'm not sure if installing PostgreSQL and RabbitMQ is necessary if we're only looking to access results from a database)

# %%
from aiida import load_profile
from aiida.orm import QueryBuilder
from aiida.orm import load_node
from aiida.orm import Node, Group, Data, Dict, CifData
import pandas as pd
load_profile()

# %% [markdown]
# ## We'll focus on the DataBase created by Ongari et al. (https://pubs.acs.org/doi/full/10.1021/acscentsci.0c00988 and https://www.materialscloud.org/discover/curated-cofs and https://archive.materialscloud.org/record/2020.107)

# %% [markdown]
# <img src="fig5.jpeg" width="1600" height="800">

# %% [markdown]
# <div style="text-align: center"><span style="font-size:0.9em;">
# ACS Cent. Sci. 2020, XXXX, XXX, XXX-XXX
# </span></div>

# %% [markdown]
# ## Querying (more on querying and filtering here https://aiida.readthedocs.io/projects/aiida-core/en/latest/topics/database.html)

# %%
qb = QueryBuilder()
qb.append(Dict)
qb.limit(10)
results = qb.all()

# %%
results[0][0].attributes
# Out:
# {'framework_1': {'general': {'box_ax_dev': 0.0,
#    'box_by_dev': 0.0,
#    'box_cz_dev': 0.0,
#    'box_ax_unit': 'A^3',
#    'box_by_unit': 'A^3',
#    'box_cz_unit': 'A^3',
#    'energy_unit': 'kJ/mol',
#    'box_beta_dev': 0.0,
#    'box_alpha_dev': 0.0,
#    'box_beta_unit': 'degrees',
#    'box_gamma_dev': 0.0,
#    'box_alpha_unit': 'degrees',
#    'box_ax_average': 54.8488,
#    'box_by_average': 27.41776,
#    'box_cz_average': 26.97482,
#    'box_gamma_unit': 'degrees',
#    'cell_volume_dev': 0.0,
#    'box_beta_average': 58.8519,
#    'cell_volume_unit': 'A^3',
#    'box_alpha_average': 89.1655,
#    'box_gamma_average': 90.7951,
#    'exceeded_walltime': False,
#    'framework_density': '747.682946025899',
#    'cell_volume_average': 40565.57463,
#    'adsorbate_density_dev': 0.51053,
#    'adsorbate_density_unit': 'kg/m^3',
#    'energy_ads/ads_tot_dev': 0.50066298811601,
#    'energy_ads/ads_vdw_dev': 0.50604161547211,
#    'framework_density_unit': 'kg/m^3',
#    'energy_host/ads_tot_dev': 2.4135866486332,
#    'energy_host/ads_vdw_dev': 2.4274799532236,
#    'energy_ads/ads_tot_final': -4.5579076367546,
#    'energy_ads/ads_vdw_final': -4.4955854351847,
#    'adsorbate_density_average': 42.111,
#    'energy_host/ads_tot_final': -200.35356362713,
#    'energy_host/ads_vdw_final': -200.01225303389,
#    'energy_ads/ads_coulomb_dev': 0.0086586837666466,
#    'energy_ads/ads_tot_average': -7.796346792667,
#    'energy_ads/ads_tot_initial': -3.3846463568101,
#    'energy_ads/ads_vdw_average': -7.796345844818,
#    'energy_ads/ads_vdw_initial': -3.3838707542556,
#    'enthalpy_of_adsorption_dev': 37.166008,
#    'tail_correction_energy_dev': 15.43679,
#    'energy_host/ads_coulomb_dev': 0.13842045914125,
#    'energy_host/ads_tot_average': -231.68513455332,
#    'energy_host/ads_tot_initial': -173.35143093644,
#    'energy_host/ads_vdw_average': -231.71527191117,
#    'energy_host/ads_vdw_initial': -173.40526743586,
#    'enthalpy_of_adsorption_unit': 'K',
#    'tail_correction_energy_unit': 'K',
#    'energy_ads/ads_coulomb_final': -0.062322201569858,
#    'energy_host/ads_coulomb_final': -0.34131059323793,
#    'energy_ads/ads_coulomb_average': -9.1459114109e-07,
#    'energy_ads/ads_coulomb_initial': -0.00077560255456083,
#    'enthalpy_of_adsorption_average': -1213.73601,
#    'tail_correction_energy_average': -21550.2169,
#    'energy_host/ads_coulomb_average': 0.03013735784725,
#    'energy_host/ads_coulomb_initial': 0.053836499497549},
#   'components': {'O2': {'mol_fraction': 1.0,
#     'partial_fugacity': 990908.01048839,
#     'partial_pressure': 1000000.0,
#     'mol_fraction_unit': '-',
#     'loading_excess_dev': 0.0487211453,
#     'loading_excess_unit': 'molecules/unit cell',
#     'loading_absolute_dev': 0.0487211453,
#     'adsorbate_density_dev': 0.51053,
#     'henry_coefficient_dev': None,
#     'loading_absolute_unit': 'molecules/unit cell',
#     'partial_fugacity_unit': 'Pa',
#     'partial_pressure_unit': 'Pa',
#     'adsorbate_density_unit': 'kg/m^3',
#     'chemical_potential_dev': None,
#     'henry_coefficient_unit': 'mol/kg/Pa',
#     'loading_excess_average': 3.26875,
#     'chemical_potential_unit': 'K',
#     'loading_absolute_average': 4.01875,
#     'adsorbate_density_average': 42.111,
#     'henry_coefficient_average': None,
#     'chemical_potential_average': None,
#     'adsorption_energy_widom_dev': None,
#     'widom_rosenbluth_factor_dev': None,
#     'adsorption_energy_widom_unit': 'kJ/mol',
#     'widom_rosenbluth_factor_unit': '-',
#     'adsorption_energy_widom_average': None,
#     'widom_rosenbluth_factor_average': None,
#     'conversion_factor_molec_uc_to_mg_g': 14.0147941227,
#     'conversion_factor_molec_uc_to_mol_kg': 0.4379896907,
#     'conversion_factor_molec_uc_to_cm3stp_gr': 9.8170903048,
#     'conversion_factor_molec_uc_to_mg_g_unit': '(mg/g)/(molec/uc)',
#     'conversion_factor_molec_uc_to_cm3stp_cm3': 7.3400710005,
#     'conversion_factor_molec_uc_to_mol_kg_unit': '(mol/kg)/(molec/uc)',
#     'conversion_factor_molec_uc_to_cm3stp_gr_unit': '(cm^3_STP/gr)/(molec/uc)',
#     'conversion_factor_molec_uc_to_cm3stp_cm3_unit': '(cm^3_STP/cm^3)/(molec/uc)'}}}}

# %%
qb = QueryBuilder()
qb.append(Dict, tag='result_dictionary')
qb.append(CifData, with_outgoing='result_dictionary')
qb.limit(10)
results = qb.all()
results
# Out:
# []

# %%
qb = QueryBuilder()
qb.append(CifData, tag='cif_structure', filters={'uuid': '2a2a4822-aaba-4de5-bbae-dba4ccb7d191'})
qb.append(Dict, with_ancestors='cif_structure')
qb.limit(10)
results = qb.all()
results
# Out:
# [[<Dict: uuid: dab00f6a-a97a-43ac-a8bd-a42e78754164 (pk: 481548)>],
#  [<Dict: uuid: 65e7f083-00a0-41e4-b4fb-d9238e8d6d71 (pk: 246430)>],
#  [<Dict: uuid: 71a85f9f-a96d-4404-b8c8-4b902c374315 (pk: 270035)>],
#  [<Dict: uuid: 59e0e875-3427-4ac1-8684-24585150c022 (pk: 222434)>],
#  [<Dict: uuid: 59e0e875-3427-4ac1-8684-24585150c022 (pk: 222434)>],
#  [<Dict: uuid: 152d33c3-7e74-4190-82cc-ea866f9f5692 (pk: 84588)>],
#  [<Dict: uuid: 152d33c3-7e74-4190-82cc-ea866f9f5692 (pk: 84588)>],
#  [<Dict: uuid: 6a95eda9-55fb-4683-8547-71bdfb5a881e (pk: 255909)>],
#  [<Dict: uuid: 152d33c3-7e74-4190-82cc-ea866f9f5692 (pk: 84588)>],
#  [<Dict: uuid: 6a95eda9-55fb-4683-8547-71bdfb5a881e (pk: 255909)>]]

# %%
results
# Out:
# [[{'md5': 'e409872be2d869073a20b1a8f68ccae0',
#    'filename': '16480N2.cif',
#    'formulae': None,
#    'scan_type': 'standard',
#    'parse_policy': 'lazy',
#    'spacegroup_numbers': None},
#   {'Density': 0.58249,
#    'Input_ha': 'DEF',
#    'POAV_A^3': 2357.67,
#    'isotherm': {'pressure': [1, 5, 10, 20, 30, 50, 80, 100, 140, 200],
#     'pressure_unit': 'bar',
#     'loading_absolute_dev': [0.0065109909529743,
#      0.043252400216982,
#      0.074954614137809,
#      0.10160498687647,
#      0.082171181833133,
#      0.12954829764376,
#      0.091573803512162,
#      0.073603364552317,
#      0.063229164814447,
#      0.14498232845544],
#     'loading_absolute_unit': 'mol/kg',
#     'loading_absolute_average': [0.24622244104334,
#      1.1741308675562,
#      2.2198037282031,
#      4.1451062819997,
#      5.8225738003748,
#      8.4799041127392,
#      11.335709658305,
#      12.757324213904,
#      14.995289898901,
#      17.26405703741],
#     'enthalpy_of_adsorption_dev': [0.19284141910487,
#      0.26572547454541,
#      0.17861252317644,
#      0.31483489228671,
#      0.37349668670441,
#      0.34013083568216,
#      0.1753315207902,
#      0.5210307550323,
#      0.43225069633251,
#      0.22931244751524],
#     'enthalpy_of_adsorption_unit': 'kJ/mol',
#     'enthalpy_of_adsorption_average': [-9.6894544910329,
#      -9.6137978598688,
#      -9.8019441603685,
#      -9.9388394735311,
#      -9.9644053943944,
#      -10.247535273919,
#      -10.200360346878,
#      -10.505706850249,
#      -10.805270592735,
#      -11.099783492554]},
#    'PONAV_A^3': 0.0,
#    'is_porous': True,
#    'Input_block': [1.51, 100],
#    'Input_volpo': [1.51, 1.51, 100000],
#    'POAV_cm^3/g': 1.02326,
#    'temperature': 298,
#    'Density_unit': 'g/cm^3',
#    'PONAV_cm^3/g': 0.0,
#    'is_kh_enough': True,
#    'POAV_A^3_unit': 'A^3',
#    'PONAV_A^3_unit': 'A^3',
#    'Unitcell_volume': 3955.56,
#    'POAV_cm^3/g_unit': 'cm^3/g',
#    'temperature_unit': 'K',
#    'PONAV_cm^3/g_unit': 'cm^3/g',
#    'POAV_Volume_fraction': 0.59604,
#    'Unitcell_volume_unit': 'A^3',
#    'PONAV_Volume_fraction': 0.0,
#    'henry_coefficient_dev': 2.22564e-09,
#    'henry_coefficient_unit': 'mol/kg/Pa',
#    'Input_structure_filename': 'tmpD0BvL3.cif',
#    'POAV_Volume_fraction_unit': None,
#    'henry_coefficient_average': 2.46138e-06,
#    'Number_of_blocking_spheres': 0,
#    'PONAV_Volume_fraction_unit': None,
#    'adsorption_energy_widom_dev': 0.0046967186,
#    'Estimated_saturation_loading': 72.958438,
#    'adsorption_energy_widom_unit': 'kJ/mol',
#    'adsorption_energy_widom_average': -7.1687636363,
#    'Estimated_saturation_loading_unit': 'mol/kg',
#    'conversion_factor_molec_uc_to_mg_g': 23.061360854,
#    'conversion_factor_molec_uc_to_mol_kg': 0.7207125712,
#    'conversion_factor_molec_uc_to_cm3stp_cm3': 9.4093501103}]]

# %% [markdown]
# ## The above methods didn't really work well enough

# %% [markdown]
# Turns out each Cif structure has its own <b>Group</b> that contains the following results:

# %% [markdown]
# |<span>|<span>|<span>|<span>|<span>|<span>|<span>|<span>|<span>|
# |---------------|----------------|-----------------|--------------------|----------------|----------------|-------------|--------------|--------------|
# | appl_ch4n2sel | appl_h2sh2osel | appl_ch4storage | appl_h2sh2osel_err | appl_h2storage | appl_o2storage | appl_pecoal | appl_peng    | appl_xekrsel |
#     | dftopt        | <b>isot_ch4</b>       | <b>isot_co2</b>        | <b>isot_n2</b>            | <b>isot_o2</b>        | <b>isotmt_h2</b>      | kh_co2qeq   | <b>kh_h2o</b>       | orig_zeopp   |
#     | kh_h2o_err    | <b>kh_h2s</b>         | <b>kh_kr</b>           | <b>kh_xe</b>              | opt_cif_ddec   | opt_zeopp      | <b>orig_cif</b>    | orig_cif_qeq |              |

# %%
qb = QueryBuilder()
qb.append(Group, tag='group', filters={'uuid': '000cd891-e0e9-41ca-9bb0-5be57038e54e'})
qb.append(Node, with_group='group', filters={'extras.tag4': 'appl_ch4storage'}, project=['attributes.wc_65bar_mol/kg_average'])
qb.append(Node, with_group='group', filters={'extras.tag4': 'appl_o2storage'}, project=['attributes.wc_140bar_wt%_dev'])
qb.limit(2)
res = qb.all()
res
# Out:
# [[13.332031016555, 0.3028980780736]]

# %%
qb = QueryBuilder()
qb.append(Group, tag='group', project='uuid')
glist = qb.all()
for i in range(len(glist)):
    if  i % 25 == 0:
        print(i)
# Out:
# 627
# 0
# 25
# 50
# 75
# 100
# 125
# 150
# 175
# 200
# 225
# 250
# 275
# 300
# 325
# 350
# 375
# 400
# 425
# 450
# 475
# 500
# 525
# 550
# 575
# 600
# 625

# %%
qb = QueryBuilder()
qb.append(Group, tag='group', project='uuid', filters={'type_string': {'!==': 'core.import'}})
group_list = qb.all()

# %%
group_list
# Out:
# [['000cd891-e0e9-41ca-9bb0-5be57038e54e'],
#  ['00226a6f-0a54-4293-8f9e-6c53fa155ae5'],
#  ['017d1e1a-7848-4251-92e3-56ac6656639a'],
#  ['017f3d02-3934-47b5-bf65-97b42776e8b7'],
#  ['018d9bcf-a998-4175-82bc-ef43a7dc763b'],
#  ['020fdc98-bae1-4625-b1f2-aa4305cc85d9'],
#  ['0275a7da-fae2-46e2-8f6c-22823057cf14'],
#  ['02ce9652-1152-497f-826e-5cb452f92179'],
#  ['02d76331-8f15-4c96-a105-8d86a22e9428'],
#  ['02f98ba0-23e6-45fa-93ce-e11bff385427'],
#  ['03432e3f-4ee6-4dfc-8da7-0483b85d8d05'],
#  ['034b8ecd-980e-46ec-ae98-dc84618c6e62'],
#  ['03a66bce-7d4d-4f5c-90f5-b5b619b60209'],
#  ['03caf051-8376-4806-b9de-53586d75fb40'],
#  ['053be00e-1928-433a-bf79-0ac7a80cac9c'],
#  ['053eccd1-8a66-4388-9535-3bbff9aa525c'],
#  ['05e5eb77-340e-4d81-b8ad-ea809512e458'],
#  ['05f2d0b8-9595-452c-8eb5-8f24311008b8'],
#  ['06127d3d-16cb-4991-bbbd-830f9b9c1e3d'],
#  ['0655a2fc-14db-40e3-b48a-9e50195fca51'],
#  ['06611df0-22f4-49fb-a0d2-081a25e2723c'],
#  ['07234570-3d35-4e63-be95-d8762a608865'],
#  ['075e5f47-f4d5-4633-a51b-0470bef2be25'],
#  ['076961be-d46d-4d90-9486-bdeedbc0b648'],
#  ['082914f4-c8ba-4411-b1ce-1b6a32140295'],
#  ['089532d5-716a-4631-bd76-1607483db6cf'],
#  ['08cac40b-231f-4a89-9ac2-49a9806d832f'],
#  ['08e2af20-c4d3-4b4b-9ebc-d69a7693c08c'],
#  ['09870bdb-dfdd-4d1b-b211-4e4b98148f87'],
#  ['09b78c4c-4b44-4c7e-9df1-65e0407a60b7'],
#  ['09fad5af-01f5-4faa-b0d2-12f2710d1a6e'],
#  ['0a33a77d-4eca-4c52-a402-d12eaebf0f19'],
#  ['0a9366e4-9406-4a0e-a981-f504888ac708'],
#  ['0af51aa6-0ec1-4ba2-971e-bbae2ad8b961'],
#  ['0bc2cbc7-12cb-476c-b28c-4210672de1a4'],
#  ['0c556399-84ca-4ce0-91c8-b45a242d440c'],
#  ['0c81b049-edc5-4dcd-be81-f18b7ddd61ae'],
#  ['0cb8fc48-3af3-4c1f-9437-24f139dee49c'],
#  ['0d431f5a-2ece-480e-ac03-7e65b6f380d3'],
#  ['0de1e197-83b5-4f37-ab97-748015f3fcf8'],
#  ['0e388604-f0b0-433c-b22e-36a81ed71208'],
#  ['0e50fb0c-85dd-4899-a44e-b586caedf996'],
#  ['0f13e6f0-ada5-44fb-831c-b5050724a296'],
#  ['10ab69ba-6373-4d0c-866f-9dd3db340fa6'],
#  ['116e2083-f4ff-4f33-aed0-09b52a26b242'],
#  ['11a1f867-2821-452d-8660-f85cb62b6f5c'],
#  ['11c04bd9-31a7-404d-b6e7-db934c71d558'],
#  ['11d4dea7-8bfb-4df1-a026-5253ad7f2aec'],
#  ['1227cf21-0aec-48c1-a96b-55bd77e28b92'],
#  ['123aa644-339b-4d00-acf5-d3a5b27646b9'],
#  ['13b9c9e6-c3c8-464b-a192-7b953ec234e2'],
#  ['14658867-f87b-4344-a2c1-0ca13e8ef61f'],
#  ['14744a49-acbd-4ef4-8928-fb59da9a1731'],
#  ['1482f2d9-0d45-4457-87f4-95d0b8f81b53'],
#  ['14adb3ba-2b02-4c54-92c4-cd786bffb48b'],
#  ['151f8f22-3541-4155-8552-153239820439'],
#  ['154923f6-5744-4ac2-aa6d-5e7f1d3d3171'],
#  ['161df0c8-6edc-418a-b138-ef7f0ee5eb35'],
#  ['16846d4b-7ffc-4144-8bd1-a642acddeb8c'],
#  ['168eea47-9c1c-4a8b-9eda-0d9f10705f7b'],
#  ['17287c9c-04bc-4364-b95e-45ae915d2d5a'],
#  ['186e5529-0229-4bef-85b4-5d00e43c1e61'],
#  ['18b34d49-89f2-424e-879f-afc5f5d58a1f'],
#  ['194d21e7-d9cc-4202-9311-ff67bde3a875'],
#  ['196d4046-a5ca-4ab4-a2ba-1567f2f9445f'],
#  ['1a437913-6915-4eb3-bb1a-a71397c6443e'],
#  ['1a5eb2b5-b1be-4d2d-819a-7f9d6c48eeb2'],
#  ['1a701feb-16a3-423e-922f-41ce35bf92b4'],
#  ['1b2ba8d0-31d4-4bbf-b187-9d6d9d6ff967'],
#  ['1b32306a-566b-4bb9-ad6f-ecb822322092'],
#  ['1b34bb5f-df85-4270-9f21-9633028fbd6b'],
#  ['1b463467-7094-4362-a123-039e144e5fa9'],
#  ['1b599258-cbbd-4aa9-9ebc-3c865132bbe1'],
#  ['1c62c553-614b-4753-aa61-24e93d5f3136'],
#  ['1d420302-bf8a-48c8-be09-17772659fe8a'],
#  ['1de57d96-8923-4dab-b941-90ffe16a59a7'],
#  ['1df4d5f1-39d5-4dfe-bfde-f15672c49e1a'],
#  ['1e4fbc26-ce33-4752-8b5e-334a6f20958b'],
#  ['1e89ece3-cd8d-405e-b9fe-304bd928aeb5'],
#  ['1f08184a-d7c2-417f-9728-4578c951ed5c'],
#  ['1f1b8386-7351-4c61-b151-affe7220e212'],
#  ['1f4389aa-3191-4ea0-8a4d-e81baf219fcd'],
#  ['1ff3e2eb-5328-48f8-8ae9-f396b9f33eb6'],
#  ['2025ae66-7d90-43a4-89cd-62450f511495'],
#  ['209ca31a-87e9-40f4-bbed-7004eebfbaa7'],
#  ['20fb8438-4669-413e-b081-a5ef6d2a8cf0'],
#  ['2162a6ce-b140-454b-b338-2a76241fbcb3'],
#  ['217462b0-a09e-4749-a5c2-65bc50673fcb'],
#  ['21821c90-6dd6-4df4-959f-3d3557a8ef9a'],
#  ['21953be6-e02b-48ac-beda-b43bbded8ab7'],
#  ['220aac11-473c-408f-ae1c-c387bdfc1983'],
#  ['22c05dec-2113-4c39-966e-651d815f7d3d'],
#  ['22c23ebb-6d64-45bd-83b4-3926df251b42'],
#  ['2378cf85-b06c-4ec4-969b-f58cfc540440'],
#  ['2495208f-64cd-4118-9f0a-7bba7db597b5'],
#  ['25391ff4-272a-4f26-a963-2ea47eef36ed'],
#  ['25ebb3ba-1f62-4f63-8725-a29f7bdfee06'],
#  ['26272d5c-9ad0-4957-8ce9-e679e9114fe8'],
#  ['2631638f-d0e0-4e25-b603-95f8a9aef533'],
#  ['26a0ce37-1068-4a27-bdc1-630e2f6faf9a'],
#  ['26e878f3-5cf4-4378-a7c2-27eddd2b8efe'],
#  ['27102533-cf73-4a34-b2ed-ded422ce884b'],
#  ['27a68275-a6df-45db-b557-a8f5fef6220e'],
#  ['281ed7eb-2604-4f44-a528-18fb46be6eb9'],
#  ['2886e671-5be7-4de2-a5e2-456892bee408'],
#  ['288d0359-0c51-4346-986a-e2283f694a14'],
#  ['2931ed94-d0ed-4178-bde1-d58abcc27e0f'],
#  ['2968b79b-00ce-4679-9ab3-80437943df34'],
#  ['29e06483-4ee2-4f61-ac8e-c3fd4c5ce957'],
#  ['29f5d3ca-91b3-4fc3-b454-8ec689001e44'],
#  ['2a5cf486-c072-4b99-9f0c-e1cf7ea5249b'],
#  ['2ac8ef45-5a0e-4f28-a3b1-c0ce61c63b80'],
#  ['2b0e6ab1-f399-4b17-a11f-3ce0ac9c5454'],
#  ['2b2ed312-b661-48b3-bf7a-1e7597dcf578'],
#  ['2b3fbdc4-1382-4252-b8c8-a45ff7df57b1'],
#  ['2ce8df0f-80c3-49c3-bdf4-726086e11ef8'],
#  ['2d182f41-b392-40b3-a644-5ccd44ad35a2'],
#  ['2eb34f48-838d-4e9b-9790-230b8ae4ef54'],
#  ['2ebc5ab5-bb49-4221-a85a-dbc53568fbff'],
#  ['2fcd2c62-2789-4aa6-8489-a8fe6505e258'],
#  ['302ab2a2-398c-4646-8bc5-c2be90cef22b'],
#  ['309a9c5c-5797-4de1-97a3-99103b7454b6'],
#  ['31ea839f-be09-4722-88e7-c3a7a4890228'],
#  ['328a2e66-1d37-45ce-8e4e-b4a709c2215d'],
#  ['32b6a89e-e8f9-4c25-a0d2-6bf6c7c2f001'],
#  ['33762ab3-9952-4f22-ab57-39ab8b5313e8'],
#  ['33ba7052-cbfc-466a-8083-fc3ea94d3814'],
#  ['34e4baab-086c-46d5-aa6f-cdc2fcb64d46'],
#  ['35f92913-db14-4071-9a2e-18aa7a72a8e6'],
#  ['372ecdaf-2ef0-47d7-bc5b-982b33e08598'],
#  ['37e6d003-5282-441c-8f62-49d165a9aacc'],
#  ['38275d8e-b3c7-40be-8d3f-49b537c9e793'],
#  ['385e04fd-27fd-43c7-b6e7-48b41072384f'],
#  ['399aed25-88d8-4018-9596-7f9b757eb6aa'],
#  ['39b145ab-04fa-4d45-bc54-394df723a72b'],
#  ['3afb307e-9ade-43d1-8034-798ff1f90151'],
#  ['3bb16f52-40e7-4d37-8980-1bf9fd958a2f'],
#  ['3bcc5d65-abb9-4989-adfe-de89d0965f2c'],
#  ['3bee205c-6510-4b3c-8f70-734c91e00b4f'],
#  ['3c213662-6c4e-40e5-993c-00a0cfabd533'],
#  ['3e0a5497-3975-4dc7-ba1c-bcac1639a91a'],
#  ['3e25e601-b84d-46e3-a3f4-1f3b5f3843ae'],
#  ['3eb097a1-842c-4de8-9c3f-f69f9cb1bcf1'],
#  ['3f1955d2-cc75-4aef-ac21-3b03dbfb9cc7'],
#  ['3fb774b4-486e-4957-8efe-fbf19c7309f3'],
#  ['3fc0b72c-2cc8-4d30-a19b-1ba6bb2a825e'],
#  ['40023994-e04d-44fc-bd02-b759bd5787da'],
#  ['402c3ef1-f50c-4791-8121-1a19520ab7fe'],
#  ['4076b946-fdd2-46a3-b87d-2c2b393a4f8c'],
#  ['415740f9-10f3-4a57-8dd5-9abaefb571c8'],
#  ['41bd8d50-fab4-4b04-becb-dadcb32c6da0'],
#  ['421b0be3-c5b9-452e-8993-acef20bbe9df'],
#  ['426c9377-65c5-4148-b603-6a0ffb52d09d'],
#  ['42a5a64b-9863-4ad1-b9e6-3a220eb9bbf4'],
#  ['4371ebb3-2aef-4a12-b8af-0891899e621c'],
#  ['45479de6-c95b-4619-9b73-ca99e7a2555e'],
#  ['45a3c73c-696e-4443-b7ec-9a96a5a001cf'],
#  ['45ea1c5f-8465-42bb-961a-60aa8388204c'],
#  ['46b63574-8971-4f2c-ae12-95407ee5bab0'],
#  ['46eda308-dc55-4942-87f9-c8f32ef8b1a3'],
#  ['4839c716-bfa2-4c2b-af59-bf8fd97ebc49'],
#  ['48b7ded5-768f-4151-8015-72daf6d364f6'],
#  ['48bf92fa-8f9d-4a7f-8702-7cec70f7d9ee'],
#  ['48c987af-18fc-4b2c-80d5-857aae911eb8'],
#  ['493e4334-7cf2-48dd-9298-de7e10fa69ef'],
#  ['49af8a47-6f96-4463-bc56-696eef41215b'],
#  ['4a2a0ad8-e5ba-47cc-8355-a27a6e4a1ab9'],
#  ['4a8d303b-9f3f-4e46-9567-559a8e6ea191'],
#  ['4aea04af-3982-401c-9d80-52faa7f8ae23'],
#  ['4c10113f-cfe8-40cf-b45d-4a5c49831ae8'],
#  ['4ca01e7a-aa02-4741-a904-d8f75e8f701f'],
#  ['4cdbdbee-c0f8-4f59-a71f-aeb0c16b7ec4'],
#  ['4ced7125-7d44-4d17-92ec-06ca7c2064e5'],
#  ['4d74fed6-d721-412c-97bd-0e164efd95e4'],
#  ['4dae5153-ee3f-49aa-9635-0ae0d2f2d0da'],
#  ['4de86884-062a-4e2c-b0de-9da0812f44db'],
#  ['4eca6f4d-9672-4627-970f-efc5dfbaab5f'],
#  ['4efc72e6-5432-48c5-ae8c-427f58ae1b38'],
#  ['4f080244-7852-465b-914c-1bd26a0731d2'],
#  ['4f41f977-5dc7-4256-8f3a-46696650eb3a'],
#  ['50ccd960-7491-4033-bf55-c80e9390f33e'],
#  ['50fbf025-e761-4552-b29e-3a3b07710ed8'],
#  ['50fea75b-6590-45a7-a340-18b4b2f44e29'],
#  ['52622378-979b-431e-b089-723cefb702aa'],
#  ['52d71847-52fd-4f73-9cf0-83d53f35bf50'],
#  ['534f0f92-04df-4a57-a324-db89d5853353'],
#  ['5392b8a5-cba5-4c4a-ac38-341d19c6b2a9'],
#  ['53b8a052-96f7-4549-a7fd-f913705e037c'],
#  ['53c5d179-7b92-4f81-8745-53888274bab4'],
#  ['53dc84c1-d4fe-4555-921c-cf3287624533'],
#  ['53e4093e-b641-41a3-9610-12754322e42b'],
#  ['540067d2-8ac3-43a2-86d8-d472a748300f'],
#  ['54215741-8963-40d2-9e6d-ec0b418f4639'],
#  ['54d1057c-afd8-4b9e-9d3d-c60afeb668d2'],
#  ['558ddaf0-2dca-43d5-b14d-8d707e328370'],
#  ['55c5773c-a1b8-4738-96b0-031fa35f4e50'],
#  ['55efdb8e-654d-4f79-966f-f224ad6600df'],
#  ['56108898-fed7-48c5-b14f-b3bc5f306bdf'],
#  ['562ecaa5-db3a-4342-87dc-4c2d6fda08ca'],
#  ['569fd66c-7246-442f-b123-c842f2762d6a'],
#  ['56b0c0e0-6093-4801-9951-b05ba22110c3'],
#  ['571c7057-6547-452d-a7e9-f5ff05731738'],
#  ['57e30aa6-e461-41c2-b491-79a45f77bb40'],
#  ['58728e8d-d288-41c2-8222-91a85cb8e0dc'],
#  ['5880db51-b680-40c6-89c2-c9359d587997'],
#  ['58ae0a4a-aba9-4299-83b5-88d558aebe2f'],
#  ['59196062-460e-4871-bf58-ba2d474d964a'],
#  ['59ad89c7-0cd2-4289-9c12-35b57443fc3b'],
#  ['59b34fb7-cb7b-4560-9879-9dcb264912de'],
#  ['5a21935b-f832-4f56-9ec8-eec7cca38235'],
#  ['5bba7040-b7c3-4b67-80e9-7b1801ce6e12'],
#  ['5bd9f088-44a4-4092-8335-b5ae66178e70'],
#  ['5cd2c39f-4d07-4508-a7b9-d28aeae9525d'],
#  ['5cf8b72a-3406-44df-bae8-9b3ac9a78d13'],
#  ['5cfeda93-7346-483d-93e0-69812aa80a38'],
#  ['5d0ffcdc-ecab-4fc0-9bb0-b39324b0db07'],
#  ['5d790fbe-7aaf-4879-97d1-ed25d16a09a6'],
#  ['5f984c98-b8a9-4ba7-b0a7-3090b7b1a929'],
#  ['5fe6222d-5d00-4fdf-9ad1-d79fe8710edf'],
#  ['5fe718d8-fdd5-4c38-9164-228881b8dafa'],
#  ['61f3f372-a49e-426b-9c7b-9e14030c9d86'],
#  ['621e3a34-12c6-49a3-bbbd-45ad0139d239'],
#  ['62ddde3e-aaea-42a4-a08c-0c903e8555a5'],
#  ['63278372-947b-441b-a2ef-4e7da37062f0'],
#  ['6399fcc8-9a70-4ba6-a750-7f23d74b8c14'],
#  ['63e8b169-93eb-417b-8bd6-21c7ad8f2701'],
#  ['640e24ce-d6b4-402c-925b-c45a204d3986'],
#  ['6477800c-8b79-48c7-bc91-eaca5174ddcb'],
#  ['64be1636-ec9f-4fe0-a73f-4b5609e7c126'],
#  ['657cb60b-8430-412d-8c9c-86d653aec8fe'],
#  ['6619766a-2b53-4001-8156-d84b9b45939b'],
#  ['665b9858-17da-42ce-aae9-2dd0761ee7a4'],
#  ['66a44788-bd4e-4516-914a-67080a24435f'],
#  ['66b87e00-bea8-4fd0-aec1-7b17a5f9bbab'],
#  ['674bac54-404b-49ea-a4c2-f269f9972da9'],
#  ['6792a2d2-ceb9-4cda-b107-bb1201f191e1'],
#  ['68bc1e22-a912-41ac-8107-1e773d0f7846'],
#  ['69170099-18ab-4df6-b584-dca0b408ca00'],
#  ['695831e4-53b8-48a1-818d-28e3f0c82e29'],
#  ['6a7742e9-01ce-4152-83fa-bfcc6e2acc76'],
#  ['6a9de570-1f4a-44a3-b3b9-e191e248dd27'],
#  ['6aaabde3-093a-4796-918c-7b110126d94b'],
#  ['6b7b4d07-339d-4bc9-81d5-b1cb78031dfb'],
#  ['6b96098a-1f1c-488a-96aa-9fd3ea5c65b9'],
#  ['6c20ac0c-a243-4897-99ec-ff8749430971'],
#  ['6ccc24e1-5a77-43a2-8adf-a9da65770e48'],
#  ['6cedc2bc-bc8f-41bd-86f9-3fc5df34b17d'],
#  ['6d3fead8-589c-491e-b8dc-ee6f0b63cfe4'],
#  ['6dbe1259-97ac-460a-ae1b-d2ebca47fe02'],
#  ['6e671e72-5460-43a9-9958-8a24b225cd57'],
#  ['6f447385-fdab-4d76-acc2-019b01b5b6bd'],
#  ['6fa1aea7-1608-455a-b568-2aec5e52843a'],
#  ['70905bdd-9137-4431-9922-4c63ac574770'],
#  ['70978e57-25ea-40a4-a1f0-00d4e6817c7b'],
#  ['70af189b-49f0-4430-943d-b6dccbc2204b'],
#  ['70cb9e7e-f1f3-4d01-b64b-0ba0469efbd4'],
#  ['7136743d-af83-4cdf-9e33-6bef1293306f'],
#  ['7199e3c6-3eb7-4f96-897a-c05069f779a9'],
#  ['7321933a-f7c2-400f-a905-f6ae93684b0a'],
#  ['7379d237-a1dc-40f6-8a42-68521be1be65'],
#  ['73f9988f-b66e-4e0d-bc96-ac38068d7ac1'],
#  ['74857f21-f722-446b-a828-55ae17a9a0b5'],
#  ['74870cd2-31cb-42ba-bf05-1607dcdaaf24'],
#  ['74e9a1c4-f76e-49b7-9a9c-bfec0f9f4d69'],
#  ['74e9cb2f-55af-4d19-89bc-74968a1b8064'],
#  ['754d90fd-f702-4fdc-8632-c89b8ae9e460'],
#  ['757dfe7f-7e7f-4c65-aa6f-a8ea314d4a08'],
#  ['76206426-d3ae-4e09-b81f-fada8b86db35'],
#  ['76ab7a23-95a1-4b29-9fbe-d3b46e86ec28'],
#  ['76c0afa2-1c31-4843-a780-7b252e8cad23'],
#  ['776fe448-f52c-4ede-87d8-f8fc40868e6c'],
#  ['77a17aab-98b1-46b2-9cb3-ed9f319f3ea4'],
#  ['77ecef4a-8d7e-4ddf-84cb-d9f3bec3d3ce'],
#  ['77ed4192-fa4e-4afb-b0ca-0fde708443b4'],
#  ['7852eea7-5b1e-4719-972c-9a4af8215cb7'],
#  ['78aa08c8-6c8d-4c49-a154-72017aca2206'],
#  ['78d75c95-c16e-44f2-91ad-ecef0c6bbd21'],
#  ['791fcfe6-5f43-4b27-8187-a492d95d66b7'],
#  ['7959aa1b-cfad-4880-8123-563025fc9276'],
#  ['79881e39-3c31-40ad-8352-c0a984242328'],
#  ['79a291d4-0a65-4f5b-b1fd-30df6927fc69'],
#  ['79bf05cb-d64c-4859-9a8b-ea7132f87de6'],
#  ['7a519ceb-b658-4a0a-a32c-5994be0ea110'],
#  ['7a53f19e-e7b0-4dc0-b853-e29798a52259'],
#  ['7bb6c1a7-1266-4c53-9b58-092996f4a454'],
#  ['7be86976-03d3-4f77-86b2-9170c45c6f34'],
#  ['7bfbcb11-0020-48e9-8944-adc209a34ff4'],
#  ['7c143c90-c871-42ad-9ec5-a1c017574739'],
#  ['7c41fe4f-cc78-450f-814c-a8975cc5b481'],
#  ['7c7a826e-2999-4f5f-b525-3cb6212295f0'],
#  ['7c992716-f92e-47c2-8807-437e5aacd591'],
#  ['7ce4876b-1ffa-462f-9caf-0368e3c64cf3'],
#  ['7cfc0468-e46d-4bac-ac00-1073ec46ca09'],
#  ['7dab8d90-4b85-44d3-8809-107d0a0227cb'],
#  ['7dbb2bd1-cc5e-48a1-bd31-af02302cb100'],
#  ['7e732594-002b-4b56-aaa2-48534df48b9a'],
#  ['7ead346f-2c1e-4536-8b29-191cc644f560'],
#  ['7eaf4ae4-7124-4592-9c01-2708c8daa8ee'],
#  ['7ec3f5cc-d0e4-4725-a3a4-4c00d555ce60'],
#  ['7ed1a0c6-8cfc-47c3-9100-8f2d1d516feb'],
#  ['7f298bdc-367e-4ff0-b7d9-b6e8ce2d6fcf'],
#  ['80d3e528-4a21-4760-b8d8-9174162a462c'],
#  ['8131b1bc-6b43-4ff6-b634-737b7b3dcaac'],
#  ['813dc6d7-6565-4bfa-82cc-89e3037d170d'],
#  ['81566720-8d2f-4ad9-9188-e36d6f39d2f3'],
#  ['8195d204-b90a-4ab5-890a-db2c30563c5b'],
#  ['81ade8e5-2a86-4df7-9c3c-dafa31ddc323'],
#  ['81be7d10-61f0-4c78-84db-9bd8b1a61266'],
#  ['825d5785-ef1e-480f-998b-cf05549bd0f7'],
#  ['82776fbf-e54d-45ed-a8cc-99232490d08c'],
#  ['835e31fa-0f4f-4bcb-ad31-635cc30ae5a8'],
#  ['835ea9c4-3330-4b8b-81a6-a0b3c3606ab0'],
#  ['83dc51e6-208b-4e07-9e28-ed5d1cb53efc'],
#  ['8523a559-7cba-4e7f-8a07-754c5d76a950'],
#  ['8537b4ce-a647-4b4d-ae86-4ddd27e29c21'],
#  ['854c7191-85b2-400e-aa6d-f6fb6ad0c3f1'],
#  ['85b2006d-90c5-455a-a17e-e2250eb727b7'],
#  ['86cb880f-9d7a-41d6-9b3d-09512b00060e'],
#  ['86ec3598-5fe4-4816-9512-d049d9251d53'],
#  ['873d358c-52bb-4db1-b4fe-62970d7a4670'],
#  ['87799d85-479b-4481-827b-931783499136'],
#  ['87a90a51-ae0b-44f4-993a-8e48ea43523e'],
#  ['87bcd245-bb10-46c2-8654-7fcd6a828857'],
#  ['887abd99-0c81-4e65-8987-2b805831db6c'],
#  ['8902b4a1-47fb-4002-941a-448f5dfacf89'],
#  ['891af5b7-0b44-4e66-a680-f77ba6a4c682'],
#  ['8a67e402-dc91-460e-b7bb-34af7ff33b07'],
#  ['8b761129-6cea-47bd-ac55-d9fafed46ab8'],
#  ['8bae8872-40e3-4628-a0c5-59c5ab770fd2'],
#  ['8bcc0844-7524-4621-84e3-ffedff6927cb'],
#  ['8bd6a38b-e565-447a-bbcd-5835869bcc1e'],
#  ['8d4f616f-8f34-4de5-9f1b-09f4d9cee239'],
#  ['8d601e0e-88ad-4d28-bd1e-611f552e265b'],
#  ['8d9331ff-7663-4784-9cd5-8da4cf437cb3'],
#  ['8e3feaff-3718-41b8-a602-b9843749e6ed'],
#  ['8e52bff3-f6dc-4aec-a48b-5d94e63cf5e3'],
#  ['8e6d250c-584e-4dde-85aa-d59b2823fbc8'],
#  ['8e962c26-f1a5-493c-9f54-a77e1ff153f0'],
#  ['8f0dbae9-223f-4dc6-a5a1-0b6cb55d6ae5'],
#  ['8ff5d701-5397-47ba-ba72-d266abab90eb'],
#  ['9006f5bf-cf4c-4c10-acae-e9d76291a282'],
#  ['907ce481-068e-4bb9-8fe0-3e7dcdf7d15c'],
#  ['9096b86b-0d2b-4b7e-9114-0fe88039f706'],
#  ['90d0f86c-86f1-47ab-9a04-3126680437a5'],
#  ['90e24c35-b3c3-4ed9-828f-584768c779d8'],
#  ['925d2d8c-c84b-4479-b2f3-b995ee8ed6e4'],
#  ['9290b9e6-71f0-4aa8-b892-c9cdacb7936c'],
#  ['92c1acac-d301-41e7-91e7-f5d62fa36240'],
#  ['92c6a76c-1b47-4573-a08a-4e029d0ed03f'],
#  ['9364048e-98a1-4f09-882b-b68c86210562'],
#  ['936c1252-7f6a-4bfb-a416-ea42da4edea9'],
#  ['93a1e9b6-9b84-4c33-8d7e-35684957730d'],
#  ['9458277b-6d0d-4b2a-8b08-c0d9b25254c5'],
#  ['94d6e9c7-956a-4b39-8b9e-faaa2bf2a0e0'],
#  ['94e7a007-a951-4ef9-861d-de7b88aba04e'],
#  ['94f34850-5056-4d77-8d3c-381c8e40eb5b'],
#  ['953c6b93-193a-49e8-a4cf-8437bb28dcaf'],
#  ['95b1d9a4-9442-4cd2-be5d-03c8b7aa9cc1'],
#  ['9668c8e3-21c4-4166-a4c3-145988cb9d45'],
#  ['968deef8-4cda-40f3-8c8e-9e1c5ce887fd'],
#  ['968ea83d-500e-4736-9f9a-345a89ae82e1'],
#  ['96c7ec56-3088-445a-958a-430bc6b77026'],
#  ['97b538cc-9157-47a7-8786-71e3b0fc8686'],
#  ['98636508-a01c-4945-aeaa-9cf213f1d84a'],
#  ['995aa082-1adc-4bc6-9d6e-ec93d9f74311'],
#  ['99602396-e452-4924-8eb5-c20695af4cb4'],
#  ['997b853f-ed20-4e44-8a99-2268e57c69ed'],
#  ['99904331-47ce-4de9-a82d-425a8592cad9'],
#  ['9a20315f-81fa-48f3-8d3e-c576c8e73dc3'],
#  ['9a5a5744-ade7-4223-ba6f-4160d1fefc50'],
#  ['9a9309ab-49ea-4ff1-a850-93cfeee0298c'],
#  ['9ab9d9e0-e6ed-43ba-a26d-7af038c48574'],
#  ['9b0e37fd-019b-4b60-b981-28b78bba9e85'],
#  ['9b1bbdb1-f69e-4ee9-84c2-f19c3d3a509e'],
#  ['9b8b3783-5904-4aba-a875-9e07fbb8a599'],
#  ['9be3f7f0-cefc-4890-854d-46aa8cd4335a'],
#  ['9cd70bd9-8b82-4508-8481-17296154b8f6'],
#  ['9cd99a41-32da-4177-907f-8e1aedfeaaa4'],
#  ['9d7619e0-e9cb-40f8-adad-2771aa25b1cf'],
#  ['9de1e706-a38d-401a-892c-0c8b2de73dc3'],
#  ['9ecaa26d-d1d7-4973-a9d2-1e3ad2db7084'],
#  ['9ed0833f-2cf7-4cf2-8cef-f49b5b8423c5'],
#  ['9feba02c-c0e7-497f-aeca-e7dcb741b7d4'],
#  ['a02572f9-abc2-4c27-9e9b-c762ea00680e'],
#  ['a0cc6aa3-c7b0-47bc-9eff-872d089693da'],
#  ['a14523dc-218c-4161-953d-0aa591f7a455'],
#  ['a19d1119-0b2f-4dcd-8d3b-9b250befaadc'],
#  ['a2111250-cba4-44ad-bd55-a0c21e583aae'],
#  ['a27ed30c-05e6-46fd-91b7-db933446a4b7'],
#  ['a2f0e5b3-2adf-4bf5-a281-b31a34518782'],
#  ['a319c866-5767-4626-82ff-54226fd26dc9'],
#  ['a32e6f1b-1d37-4b2f-9b05-162a46c305fd'],
#  ['a35e180d-e9a3-485e-b3ed-8d71f44ee742'],
#  ['a4d4ab90-a340-4155-b7ce-8053efb5e555'],
#  ['a621f039-418d-40bd-9bda-5fb25481a9c9'],
#  ['a68de4a0-ee6d-4ce6-9451-054c7ebd48db'],
#  ['a76738ee-677a-4619-ab1e-ead71b4c92b5'],
#  ['a7b06d33-879f-4f72-ab8d-470dfff8cfd1'],
#  ['a80e17ed-cb46-418b-b5be-224675ae0b19'],
#  ['a8480e0c-2a12-4c94-b587-267287864a77'],
#  ['a8650658-ec85-4032-b46e-15baa746398b'],
#  ['a88cb406-cabf-4ce8-a824-2ff1503575d5'],
#  ['a935336b-6051-4d39-a482-fdcfabd93c3a'],
#  ['a96a78db-6617-490e-9b48-212bd80c6cd5'],
#  ['a9ba4181-1dcd-4814-971e-497197272b62'],
#  ['a9cf3334-98e1-465f-8277-d24e5d5e8ff0'],
#  ['a9d17205-1fd7-4db4-bc22-f78d4dbc81a5'],
#  ['ab1fe0bf-771a-4982-84d5-52d80dfa0d50'],
#  ['ab31918c-40f4-41fe-bcc9-3905e1a54cc5'],
#  ['ab5fbe6f-5ae9-4419-acc7-9a76027305ec'],
#  ['ab908efc-6c1b-4c0d-b84d-ff6efe23f770'],
#  ['ab9b8d23-e279-489f-b272-d1c62261c6f4'],
#  ['ac2cd053-7f67-4e61-a57e-1a5668d4ac5c'],
#  ['ac6bd606-bb73-44ad-bacb-0905f32059c3'],
#  ['ad34fc5f-6f18-47f2-8a38-f0a3aa88b554'],
#  ['add4c99d-9b74-4802-af4c-91c084b17ca0'],
#  ['adebd135-a229-4d25-a590-fdffdc5a6150'],
#  ['adfc2db9-a85c-4946-9f7f-0bcdc0d02b16'],
#  ['af7f8ab6-7b92-4fa5-8e2b-da8ced62c4ad'],
#  ['afded5ae-f970-4f17-ab12-10d248f75d88'],
#  ['b053b5d5-5015-45e3-a221-e505f4f1c709'],
#  ['b0b4c8c7-b880-4bfb-807f-f919090c1739'],
#  ['b0d46416-26d4-4610-acd7-4c7668344b09'],
#  ['b0fb8142-fd25-4d06-bcc6-b1753c8ea156'],
#  ['b138e0ee-6f7c-477d-9c08-61e773062945'],
#  ['b142a2dd-780b-4ced-804f-a225721e22b7'],
#  ['b1dc429c-0d34-4790-88c8-664d864802f6'],
#  ['b2fd4633-8f33-4764-bc79-8a0f24dde828'],
#  ['b360da84-2674-4d18-b92e-9b051d0dceab'],
#  ['b3c41261-9076-450b-9163-12a36db7e800'],
#  ['b4459eda-c941-4518-80d5-a9dd218850bb'],
#  ['b5508628-257a-45bd-8931-faf72f7c71bc'],
#  ['b560dd5a-3734-4bdb-a37a-d86f1983b1af'],
#  ['b5a90a24-738d-4eef-b605-3e0d3418f936'],
#  ['b5b3615e-1508-4465-a0dd-726622172a77'],
#  ['b5e0ff62-4c1b-4617-b1bf-15947332ca9b'],
#  ['b612ad28-e27f-4024-8cb2-a9653d6bf643'],
#  ['b666d6bc-8be0-425a-a72e-cafd5d089ecc'],
#  ['b69e6b30-237e-4702-878e-3c24e5f0001a'],
#  ['b6a40d37-3824-458f-a0c9-d19f67b4f76c'],
#  ['b7fc1a4a-79ad-4183-83a0-c0f8d4fa128c'],
#  ['ba13eb20-fe69-44b8-8a58-51398d3934f6'],
#  ['ba68e570-17c1-4a4e-8c1a-9cf1d208dec6'],
#  ['ba7619d7-4ac7-43ff-b042-232353a38632'],
#  ['bb1a93a6-95fd-4f9f-935a-a68bbad4a64e'],
#  ['bbaa8a81-5b33-4918-b3aa-fc10b6e6d93a'],
#  ['bc7c4c3f-4f76-495d-ad3d-4b234437e989'],
#  ['bc8e5ed9-a067-4992-a5c2-17b97a0cdadf'],
#  ['bd669cd5-0d36-4bda-85ac-84e2512bdbc5'],
#  ['bdfe60d9-5f8d-4e78-aecd-46a5444b80d8'],
#  ['be2a2c10-bd77-4688-ae1d-2178b7194828'],
#  ['bea41244-ae59-42ef-9ebb-f34d7b5df0c7'],
#  ['bf6eacad-dd5e-4731-b335-595cb878e392'],
#  ['bfcc2b4d-e10f-4289-9abf-9bda22df6c6d'],
#  ['c0285af2-8067-43c0-aa92-1477ed8ecd7f'],
#  ['c049c037-a638-478d-b240-dcabdd2c17cf'],
#  ['c08fb68c-85ee-4130-bed1-bd62cf1f3c6d'],
#  ['c0987e0b-23c8-4ff6-b854-1ba94a57ca63'],
#  ['c0ec4567-3fc1-4dc4-9338-f1e0f448e257'],
#  ['c185c893-0476-4d6d-930c-f12ed828dad6'],
#  ['c19205bb-51fd-41b1-92a0-b13770050544'],
#  ['c1d8a862-c826-4469-a036-74b80c201b4b'],
#  ['c275d965-70da-454e-b145-30ffdf32c3b5'],
#  ['c29d61f7-11ab-4cd4-9dc2-99b1c3b11305'],
#  ['c2b9ce0f-71a6-4346-969a-be689d84f892'],
#  ['c2c0b8b6-5075-4a5f-a583-f477c55a451b'],
#  ['c31ef7ce-d08e-4fb8-af59-0834eb7c4ef6'],
#  ['c3a22e9c-87cf-4ad6-8e75-6ef7a2873e07'],
#  ['c3fc2e54-f048-400d-8085-a8b1efebfbae'],
#  ['c4022f1e-c68b-4d00-8b7a-ffdf1104e05e'],
#  ['c43dadbc-9767-410e-8659-2306b42cae29'],
#  ['c4c23a5b-3d38-4ff7-97a1-542ff307d088'],
#  ['c59b8f2c-96f7-40c5-b44d-d0dfe9eb27ee'],
#  ['c5b65ea4-5657-4f17-b942-e8300d3d044b'],
#  ['c67ac880-2582-44c7-945e-7099d8402a8a'],
#  ['c6a9ff66-e61e-4e20-8cc5-c4cbdaae851a'],
#  ['c7336c58-0c2a-4ec1-b7fd-66bf05d2e988'],
#  ['c770519d-471e-4871-baa7-ad7751362bc8'],
#  ['c7b1981a-875a-48e7-9a4a-463dcf4ea953'],
#  ['c85202ce-e238-4e8a-bd0c-4910b32f1cc2'],
#  ['c8557453-4a20-4bbd-91d0-32e9952d2f5c'],
#  ['c8640135-81b1-4601-8754-5f8181b1cdd2'],
#  ['c8852831-0ced-4775-93e5-cce5f0db6635'],
#  ['c8b5a763-205f-4887-a46a-ea0aebd4c3aa'],
#  ['ca2afcb5-9874-4b56-becf-4c8ab0dc552b'],
#  ['cba1e8a4-59f5-43e4-b92c-acff212505d2'],
#  ['cbc627df-20c2-462f-b9d6-e9f9a5e40294'],
#  ['cc0ea7ec-c856-415a-b853-27594402812b'],
#  ['cc342186-9f4c-4d68-9a52-99c3031ce2cd'],
#  ['cc482921-f7d3-4715-a03c-982eb1bffe20'],
#  ['cc8d885a-4439-40d7-b5fe-a2ea5af0f364'],
#  ['cc91c2f1-0d90-4f68-88e9-01955597f92b'],
#  ['cd2e19b6-9cee-4526-8a45-97072e72a4a8'],
#  ['cd4e1f2a-f09f-41f6-93b3-7413382ce762'],
#  ['cd56a58b-0a44-4bab-bdcb-a8264ff33e51'],
#  ['cd903218-09c2-4faa-881d-b5a100e116e7'],
#  ['ce69eba0-d26d-4082-a089-069d0eaf6ef2'],
#  ['ce75ba6d-4a88-400c-b0b4-2a359525752f'],
#  ['ce8268d8-370f-463e-b5ee-368ac01fe2e3'],
#  ['ce9bba50-a2fe-400f-be18-e8897c065406'],
#  ['cefe6083-90bb-4909-ac32-4c0f9950fc6e'],
#  ['cf2b4c3f-b8f1-4f35-903d-ca182eefe7a5'],
#  ['cf5aa18a-684a-4457-b22a-d0a2a98e2d8c'],
#  ['cfb12625-7600-4f63-a580-a0c6357b64c5'],
#  ['d04d6f7f-3a36-4df5-b1ca-90b99f1fd406'],
#  ['d17a12ec-9a3b-4104-a29d-dd1f35ab6ce5'],
#  ['d18cb799-90f6-4a03-aa5f-efe6a241d06c'],
#  ['d192230e-f430-4669-b2f1-bad933910be5'],
#  ['d196f1e0-e029-442b-a90a-19d77a61ebea'],
#  ['d2c3cac5-b55f-48f2-b0ff-4b8db174b885'],
#  ['d2d9cbaa-a0ce-4da6-aeee-6afc3bedb801'],
#  ['d3df6c89-87ef-458c-aced-b1f8a51fedf6'],
#  ['d3f2230f-6d6d-44db-9200-5f54f624d86d'],
#  ['d3fe607d-0244-4e54-9dd0-f199f4afd4d2'],
#  ['d47a4f93-8127-4986-a78d-ba6748a61e39'],
#  ['d4abea21-99c9-4a88-bea4-bb2a9e7b395d'],
#  ['d4e90404-c5bc-415b-8b5c-a6b2bc07b53a'],
#  ['d509b921-533d-46ff-af6d-821e707d7721'],
#  ['d59123d8-36f1-46cc-9a8f-ce526f646dde'],
#  ['d5b70d39-8c13-4988-bd63-fc9950e626cd'],
#  ['d679b2d7-c9e7-46ef-aed2-55ebc5828ed4'],
#  ['d742d1d3-78b0-45bd-9306-c9425f9afd45'],
#  ['d77a3f9d-05ba-4622-a387-b006f14c247a'],
#  ['d78653c2-37a0-41e8-ad2e-f317353b8ff6'],
#  ['d7c95f89-9cd5-4c4a-b469-88fa6fc802d7'],
#  ['d7db2560-2b4a-4e1e-bfc8-6ca292bb84d8'],
#  ['d80b756c-44cb-4a6f-ac9f-237f8e9a512c'],
#  ['d940d2ed-b1c5-431e-82fd-7e8398fdfa32'],
#  ['d9abe59b-7b6c-432e-a06a-0efccfc9d2af'],
#  ['d9d80135-eff8-4572-af04-6dba0c66d3ca'],
#  ['da0c9ba5-7c19-4aac-952f-e7f233ac2c40'],
#  ['da1cfd6a-b41e-4a82-b371-a660489976fb'],
#  ['da2ebed2-d2c4-41c0-aaf9-081012eadd07'],
#  ['da59415f-a1fc-47bf-861e-e1398c8a16eb'],
#  ['da97318a-3f3e-4522-8bf4-fc1001888de3'],
#  ['dbe00af9-cb83-4894-b91a-e628fb75a75c'],
#  ['dcdd9a3e-0915-4374-a562-5d83842f594b'],
#  ['ddfbe968-51ed-4634-b708-857d4ae6015c'],
#  ['de3c634a-e096-4b0f-a740-ffbf326f7e5f'],
#  ['de721f52-88b5-4b1f-a645-e59755abbac3'],
#  ['df496481-5f0c-4106-99a2-4c6cf6ae19a0'],
#  ['df9929a8-c541-4502-b756-951d8b05764b'],
#  ['dfed5f20-006c-418d-af0b-e5c5b9a71a05'],
#  ['e03a4036-77ad-4aed-80d7-c308a209e7f9'],
#  ['e0862997-d5fa-4675-b5fc-314a055d8370'],
#  ['e0cc72fe-86cf-431b-92f8-2e412d954280'],
#  ['e0d46751-8350-42f4-b5df-f231b77baba4'],
#  ['e0e79e42-baae-4c43-8753-0b362638f2bf'],
#  ['e1005c11-c16c-443f-98d7-a11bd5c8bd44'],
#  ['e10c257a-155f-43fb-a3fa-87cdc42197a1'],
#  ['e1634b3b-ad1d-4907-ae3a-737c0d397d3c'],
#  ['e189006a-7aac-4db7-95cb-5f9ce096d3a0'],
#  ['e1ad6f09-d9a5-4dcc-8cc2-f90f564e93ff'],
#  ['e230a748-8f01-43ee-915e-b9a9c2c5daaf'],
#  ['e2498ad4-9b22-4c34-a8da-9851275b7998'],
#  ['e2a67210-713b-4eb1-9a07-399e9ce36212'],
#  ['e33f5390-d58b-4194-8519-4bafb0698230'],
#  ['e3f6e297-f74c-4947-8d6e-25e208f3f272'],
#  ['e44d45eb-a994-4d84-b33a-d651f01a7af6'],
#  ['e47f13bc-2012-465f-86e0-58fadb9bdcf5'],
#  ['e4e3e677-9ab2-43e3-b6a0-a1c0bd649871'],
#  ['e60530cf-a76f-4d2d-b01d-1ed243501534'],
#  ['e61e295f-6423-4398-9f8e-19fd5ebffe66'],
#  ['e66a66d3-8f01-4560-a37c-d909104d417b'],
#  ['e6e4b272-28d7-4ed3-abca-6e7716543b3b'],
#  ['e6f7bbe8-59ea-4e22-8da1-7b6ef20b19cd'],
#  ['e74258b1-e896-47f4-8102-e7839e86e24b'],
#  ['e775668d-32f3-4768-845b-dfa490c2f4f2'],
#  ['e7d29493-e1da-4a9f-aeac-f2ff0cdfb0cf'],
#  ['e7db89ba-7629-478a-a6b4-0a76ad799a32'],
#  ['e8aaa628-871f-4ea9-8ffa-e09193dff4ea'],
#  ['ea12c85c-fde1-40e1-a4ec-be6c6e612b23'],
#  ['ea4f1165-3aaf-4a3f-97da-06d690d5521f'],
#  ['eae313f0-51db-40d7-afb0-d43c319163bc'],
#  ['eb1509a1-4875-427c-8b74-21ced138ff37'],
#  ['eb9d692d-d9a9-4b24-91ea-4f66cd41d767'],
#  ['ebc30d52-c383-4650-a6ef-9e702a8a47cf'],
#  ['ec3a638c-c4b1-45f8-80cc-752dc458568c'],
#  ['ec4a6e08-3064-4f6b-a06d-38b351318dba'],
#  ['ec696695-ffc8-4a35-856c-1c09707c4e8d'],
#  ['ecbe82b7-bf77-4194-b957-16c952fd379d'],
#  ['ed367208-0936-4ab7-9ba5-5a3cd9e6824d'],
#  ['ee666460-7daf-42b4-bfa0-917a4277ebfd'],
#  ['eebff9b9-5431-45ae-bb40-574e4b49ac5e'],
#  ['ef29dffd-fbd5-4483-b396-0a47161a00a7'],
#  ['ef8a9223-597c-41dd-8b0c-45f15e631dc8'],
#  ['eff22987-5257-48ff-88a3-9e8df9beb8ed'],
#  ['f0e36205-df34-4e65-a717-7f9d356d2dd3'],
#  ['f104d15f-a185-411d-acc9-f72195e3ec88'],
#  ['f138d798-0362-4f39-8a9d-5631975385bd'],
#  ['f1630124-1b88-4660-b1e7-1b55852a8a77'],
#  ['f2ca43e4-9aff-42ed-a2be-c399836595b3'],
#  ['f35658cb-a9c3-4afe-a633-4a187f39a6b4'],
#  ['f3d0f852-1918-46b1-a11a-bad41db2cb3a'],
#  ['f505d0c0-aefc-49e1-8a25-2cdc3a129d01'],
#  ['f5569822-dddc-450b-84be-534e9057bf19'],
#  ['f56e8232-4ca2-4f7f-8a77-8c365e5b1364'],
#  ['f576ef9d-d716-4726-b46d-2c107e709853'],
#  ['f616d482-13d2-4607-a651-6a9ab56ec440'],
#  ['f69ac66f-2525-4c6a-b78a-657a1be5e175'],
#  ['f6a4b03e-afa1-4979-8775-f97ad978e2a8'],
#  ['f77ecd78-518c-455d-a000-1fb9de7d6e62'],
#  ['f7e0fc36-c7b1-472a-96d9-f555e92559b5'],
#  ['f7f72225-6f29-4382-8ad7-d6f0aee11200'],
#  ['f80a7a40-83a1-4502-93e4-85dc9f703776'],
#  ['f8260f44-2047-42a8-a4fe-88b7570cc863'],
#  ['f872eef6-7878-4180-bc6b-5b9cee26760a'],
#  ['fa0397a4-938e-412b-b199-feda540b7b9d'],
#  ['fa7255a0-88e9-4dd8-abad-d5d570af6548'],
#  ['fac013b9-730a-47a7-88e1-0841fd24df81'],
#  ['fae81e5d-b577-48bb-a9bb-f504de20e2b0'],
#  ['fb7be2b0-8e94-4442-bf9a-8be7353b9dcb'],
#  ['fca10393-6963-45f9-8e22-bf482382a5df'],
#  ['fceb5c30-bcf3-478c-b26f-895433a4b2d3'],
#  ['fd73ae7c-5c08-4cc1-9678-d083ca7c91a1'],
#  ['fe068584-9d40-4ed4-90c9-2401d4f82b86'],
#  ['fe610f91-94c4-4645-9a7e-7245c8d8b106'],
#  ['fe8d6032-847c-4788-a8dd-947848ef9c38'],
#  ['fe93bd8a-de0e-4304-bfbf-affd41ba83f7'],
#  ['fed7cf6a-f32b-4317-92a8-3aa474ae4e62'],
#  ['ff476c05-02a7-4351-bd2c-83ac5228e7f7'],
#  ['ff5edcdd-a9d2-4f86-931a-32376c175c3f'],
#  ['ff69b07e-52f5-4de8-a12c-eabda564c7d7'],
#  ['ffbd84e1-a6c0-4d6e-b525-6a95919430ba'],
#  ['fffc2462-b7ee-43be-aa02-fb1a0e246538']]

# %%
qb = QueryBuilder()
qb.append(Group, tag='cif_group', filters={'uuid': group_list[0][0]})
qb.append(CifData, with_group='cif_group', filters={'extras.tag4': 'orig_cif'}, project='attributes')
qb.append(Dict, with_group='cif_group', filters={'extras.tag4': 'isot_ch4'}, project='attributes')
results = qb.all()
results
# Out:
# [[{'md5': 'd50454ca17af699615b416fca5747e07',
#    'filename': '20040N2.cif',
#    'formulae': [None],
#    'scan_type': 'standard',
#    'parse_policy': 'eager',
#    'spacegroup_numbers': [None]},
#   {'Density': 0.464398,
#    'Input_ha': 'DEF',
#    'POAV_A^3': 6518.73,
#    'isotherm': {'pressure': [1.0, 5.8, 20, 35, 50, 65],
#     'pressure_unit': 'bar',
#     'loading_absolute_dev': [0.091465782971059,
#      0.10643056579762,
#      0.2515710518384,
#      0.11813181790562,
#      0.098621988028515,
#      0.20258721012854],
#     'loading_absolute_unit': 'mol/kg',
#     'loading_absolute_average': [1.1149499874431,
#      4.2150522857816,
#      9.7188967840883,
#      13.199184394717,
#      15.661772457412,
#      17.547083302337],
#     'enthalpy_of_adsorption_dev': [0.66341837320097,
#      1.040702393721,
#      0.3604837245267,
#      0.56759690869938,
#      0.4397069333932,
#      0.34233739908375],
#     'enthalpy_of_adsorption_unit': 'kJ/mol',
#     'enthalpy_of_adsorption_average': [-17.233875765966,
#      -13.621280420377,
#      -12.613551669951,
#      -12.023121565106,
#      -12.293622508792,
#      -12.232164658735]},
#    'PONAV_A^3': 0.0,
#    'is_porous': True,
#    'Input_block': [1.865, 100],
#    'Input_volpo': [1.865, 1.865, 100000],
#    'POAV_cm^3/g': 1.36527,
#    'temperature': 298,
#    'Density_unit': 'g/cm^3',
#    'PONAV_cm^3/g': 0.0,
#    'is_kh_enough': True,
#    'POAV_A^3_unit': 'A^3',
#    'PONAV_A^3_unit': 'A^3',
#    'Unitcell_volume': 10281.4,
#    'POAV_cm^3/g_unit': 'cm^3/g',
#    'temperature_unit': 'K',
#    'PONAV_cm^3/g_unit': 'cm^3/g',
#    'POAV_Volume_fraction': 0.63403,
#    'Unitcell_volume_unit': 'A^3',
#    'PONAV_Volume_fraction': 0.0,
#    'henry_coefficient_dev': 4.45147e-07,
#    'henry_coefficient_unit': 'mol/kg/Pa',
#    'Input_structure_filename': 'tmpjj7mp23z.cif',
#    'POAV_Volume_fraction_unit': None,
#    'henry_coefficient_average': 1.47235e-05,
#    'Number_of_blocking_spheres': 0,
#    'PONAV_Volume_fraction_unit': None,
#    'adsorption_energy_widom_dev': 0.230285267,
#    'Estimated_saturation_loading': 35.9612118,
#    'adsorption_energy_widom_unit': 'kJ/mol',
#    'adsorption_energy_widom_average': -17.3693715846,
#    'Estimated_saturation_loading_unit': 'mol/kg',
#    'conversion_factor_molec_uc_to_mg_g': 5.5785321402,
#    'conversion_factor_molec_uc_to_mol_kg': 0.3477887868,
#    'conversion_factor_molec_uc_to_cm3stp_cm3': 3.6200507719}]]

# %%
resul
